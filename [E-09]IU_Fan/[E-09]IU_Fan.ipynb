# %%
#!mkdir -p ~/aiffel/recommendata_iu/data/lastfm-dataset-360K
#!ln -s ~/data/lastfm-dataset-360K/* ~/aiffel/recommendata_iu/data/lastfm-dataset-360K
# Out:
# ln: failed to create symbolic link '/aiffel/aiffel/recommendata_iu/data/lastfm-dataset-360K/mbox_sha1sum.py': File exists
# ln: failed to create symbolic link '/aiffel/aiffel/recommendata_iu/data/lastfm-dataset-360K/README.txt': File exists
# ln: failed to create symbolic link '/aiffel/aiffel/recommendata_iu/data/lastfm-dataset-360K/usersha1-artmbid-artname-plays.tsv': File exists
# ln: failed to create symbolic link '/aiffel/aiffel/recommendata_iu/data/lastfm-dataset-360K/usersha1-profile.tsv': File exists

# %%
#!more ~/aiffel/recommendata_iu/data/lastfm-dataset-360K/usersha1-artmbid-artname-plays.tsv
# Out:
# 00000c289a1829a808ac09c00daf10bc3c4e223b	3bd73256-3905-4f3a-97e2-8b341527
# f805	betty blowtorch	2137
# 00000c289a1829a808ac09c00daf10bc3c4e223b	f2fb0ff0-5679-42ec-a55c-15109ce6
# e320	die Ärzte	1099
# 00000c289a1829a808ac09c00daf10bc3c4e223b	b3ae82c2-e60b-4551-a76d-6620f1b4
# 56aa	melissa etheridge	897
# 00000c289a1829a808ac09c00daf10bc3c4e223b	3d6bbeb7-f90e-4d10-b440-e153c0d1
# 0b53	elvenking	717
# 00000c289a1829a808ac09c00daf10bc3c4e223b	bbd2ffd7-17f4-4506-8572-c1ea58c3
# f9a8	juliette & the licks	706
# 00000c289a1829a808ac09c00daf10bc3c4e223b	8bfac288-ccc5-448d-9573-c33ea2aa
# 5c30	red hot chili peppers	691
# 00000c289a1829a808ac09c00daf10bc3c4e223b	6531c8b1-76ea-4141-b270-eb1ac5b4
# 1375	magica	545
# 00000c289a1829a808ac09c00daf10bc3c4e223b	21f3573f-10cf-44b3-aeaa-26cccd84
# 48b5	the black dahlia murder	507
# 00000c289a1829a808ac09c00daf10bc3c4e223b	c5db90c4-580d-4f33-b364-fbaa5a3a
# 58b5	the murmurs	424
# 00000c289a1829a808ac09c00daf10bc3c4e223b	0639533a-0402-40ba-b6e0-18b06719
# 8b73	lunachicks	403
# 00000c289a1829a808ac09c00daf10bc3c4e223b	a342964d-ca53-4e54-96dc-e8501851
# e77f	walls of jericho	393
# 00000c289a1829a808ac09c00daf10bc3c4e223b	f779ed95-66c8-4493-9f46-3967eba7
# m--More--(0%)

# %%
import pandas as pd
import os

fname = os.getenv('HOME') + '/aiffel/recommendata_iu/data/lastfm-dataset-360K/usersha1-artmbid-artname-plays.tsv'
col_names = ['user_id', 'artist_MBID', 'artist', 'play']   # 임의로 지정한 컬럼명
data = pd.read_csv(fname, sep='\t', names= col_names)      # sep='\t'로 주어야 tsv를 열 수 있습니다.
data.head(10)
# Out:
#                                     user_id  \
# 0  00000c289a1829a808ac09c00daf10bc3c4e223b
# 1  00000c289a1829a808ac09c00daf10bc3c4e223b
# 2  00000c289a1829a808ac09c00daf10bc3c4e223b
# 3  00000c289a1829a808ac09c00daf10bc3c4e223b
# 4  00000c289a1829a808ac09c00daf10bc3c4e223b
# 5  00000c289a1829a808ac09c00daf10bc3c4e223b
# 6  00000c289a1829a808ac09c00daf10bc3c4e223b
# 7  00000c289a1829a808ac09c00daf10bc3c4e223b
# 8  00000c289a1829a808ac09c00daf10bc3c4e223b
# 9  00000c289a1829a808ac09c00daf10bc3c4e223b
#
#                             artist_MBID                   artist  play
# 0  3bd73256-3905-4f3a-97e2-8b341527f805          betty blowtorch  2137
# 1  f2fb0ff0-5679-42ec-a55c-15109ce6e320                die Ärzte  1099
# 2  b3ae82c2-e60b-4551-a76d-6620f1b456aa        melissa etheridge   897
# 3  3d6bbeb7-f90e-4d10-b440-e153c0d10b53                elvenking   717
# 4  bbd2ffd7-17f4-4506-8572-c1ea58c3f9a8     juliette & the licks   706
# 5  8bfac288-ccc5-448d-9573-c33ea2aa5c30    red hot chili peppers   691
# 6  6531c8b1-76ea-4141-b270-eb1ac5b41375                   magica   545
# 7  21f3573f-10cf-44b3-aeaa-26cccd8448b5  the black dahlia murder   507
# 8  c5db90c4-580d-4f33-b364-fbaa5a3a58b5              the murmurs   424
# 9  0639533a-0402-40ba-b6e0-18b067198b73               lunachicks   403

# %%
# 사용하는 컬럼만 남겨줍니다.
using_cols = ['user_id', 'artist', 'play']
data = data[using_cols]
data.head(10)
# Out:
#                                     user_id                   artist  play
# 0  00000c289a1829a808ac09c00daf10bc3c4e223b          betty blowtorch  2137
# 1  00000c289a1829a808ac09c00daf10bc3c4e223b                die Ärzte  1099
# 2  00000c289a1829a808ac09c00daf10bc3c4e223b        melissa etheridge   897
# 3  00000c289a1829a808ac09c00daf10bc3c4e223b                elvenking   717
# 4  00000c289a1829a808ac09c00daf10bc3c4e223b     juliette & the licks   706
# 5  00000c289a1829a808ac09c00daf10bc3c4e223b    red hot chili peppers   691
# 6  00000c289a1829a808ac09c00daf10bc3c4e223b                   magica   545
# 7  00000c289a1829a808ac09c00daf10bc3c4e223b  the black dahlia murder   507
# 8  00000c289a1829a808ac09c00daf10bc3c4e223b              the murmurs   424
# 9  00000c289a1829a808ac09c00daf10bc3c4e223b               lunachicks   403

# %%
data['artist'] = data['artist'].str.lower() # 검색을 쉽게하기 위해 아티스트 문자열을 소문자로 바꿔줍시다.
data.head(10)
# Out:
#                                     user_id                   artist  play
# 0  00000c289a1829a808ac09c00daf10bc3c4e223b          betty blowtorch  2137
# 1  00000c289a1829a808ac09c00daf10bc3c4e223b                die ärzte  1099
# 2  00000c289a1829a808ac09c00daf10bc3c4e223b        melissa etheridge   897
# 3  00000c289a1829a808ac09c00daf10bc3c4e223b                elvenking   717
# 4  00000c289a1829a808ac09c00daf10bc3c4e223b     juliette & the licks   706
# 5  00000c289a1829a808ac09c00daf10bc3c4e223b    red hot chili peppers   691
# 6  00000c289a1829a808ac09c00daf10bc3c4e223b                   magica   545
# 7  00000c289a1829a808ac09c00daf10bc3c4e223b  the black dahlia murder   507
# 8  00000c289a1829a808ac09c00daf10bc3c4e223b              the murmurs   424
# 9  00000c289a1829a808ac09c00daf10bc3c4e223b               lunachicks   403

# %%
condition = (data['user_id']== data.loc[0, 'user_id'])
data.loc[condition]
# Out:
#                                      user_id                   artist  play
# 0   00000c289a1829a808ac09c00daf10bc3c4e223b          betty blowtorch  2137
# 1   00000c289a1829a808ac09c00daf10bc3c4e223b                die ärzte  1099
# 2   00000c289a1829a808ac09c00daf10bc3c4e223b        melissa etheridge   897
# 3   00000c289a1829a808ac09c00daf10bc3c4e223b                elvenking   717
# 4   00000c289a1829a808ac09c00daf10bc3c4e223b     juliette & the licks   706
# 5   00000c289a1829a808ac09c00daf10bc3c4e223b    red hot chili peppers   691
# 6   00000c289a1829a808ac09c00daf10bc3c4e223b                   magica   545
# 7   00000c289a1829a808ac09c00daf10bc3c4e223b  the black dahlia murder   507
# 8   00000c289a1829a808ac09c00daf10bc3c4e223b              the murmurs   424
# 9   00000c289a1829a808ac09c00daf10bc3c4e223b               lunachicks   403
# 10  00000c289a1829a808ac09c00daf10bc3c4e223b         walls of jericho   393
# 11  00000c289a1829a808ac09c00daf10bc3c4e223b           letzte instanz   387
# 12  00000c289a1829a808ac09c00daf10bc3c4e223b                goldfrapp   361
# 13  00000c289a1829a808ac09c00daf10bc3c4e223b               horrorpops   358
# 14  00000c289a1829a808ac09c00daf10bc3c4e223b             the butchies   329
# 15  00000c289a1829a808ac09c00daf10bc3c4e223b            jack off jill   316
# 16  00000c289a1829a808ac09c00daf10bc3c4e223b         babes in toyland   310
# 17  00000c289a1829a808ac09c00daf10bc3c4e223b         dropkick murphys   302
# 18  00000c289a1829a808ac09c00daf10bc3c4e223b            all:my:faults   288
# 19  00000c289a1829a808ac09c00daf10bc3c4e223b                 le tigre   281
# 20  00000c289a1829a808ac09c00daf10bc3c4e223b               schandmaul   244
# 21  00000c289a1829a808ac09c00daf10bc3c4e223b                    edguy   232
# 22  00000c289a1829a808ac09c00daf10bc3c4e223b      maximum the hormone   231
# 23  00000c289a1829a808ac09c00daf10bc3c4e223b                 all ends   229
# 24  00000c289a1829a808ac09c00daf10bc3c4e223b             jack johnson   227
# 25  00000c289a1829a808ac09c00daf10bc3c4e223b                eluveitie   222
# 26  00000c289a1829a808ac09c00daf10bc3c4e223b                rasputina   220
# 27  00000c289a1829a808ac09c00daf10bc3c4e223b    london after midnight   210
# 28  00000c289a1829a808ac09c00daf10bc3c4e223b              the killers   208
# 29  00000c289a1829a808ac09c00daf10bc3c4e223b                  mutyumu   205
# 30  00000c289a1829a808ac09c00daf10bc3c4e223b             judas priest   198
# 31  00000c289a1829a808ac09c00daf10bc3c4e223b               rob zombie   198
# 32  00000c289a1829a808ac09c00daf10bc3c4e223b             the bosshoss   189
# 33  00000c289a1829a808ac09c00daf10bc3c4e223b         blue öyster cult   185
# 34  00000c289a1829a808ac09c00daf10bc3c4e223b             sandra nasic   183
# 35  00000c289a1829a808ac09c00daf10bc3c4e223b               john mayer   182
# 36  00000c289a1829a808ac09c00daf10bc3c4e223b           sleater-kinney   175
# 37  00000c289a1829a808ac09c00daf10bc3c4e223b                  the who   168
# 38  00000c289a1829a808ac09c00daf10bc3c4e223b                 disciple   154
# 39  00000c289a1829a808ac09c00daf10bc3c4e223b                  tanzwut   153
# 40  00000c289a1829a808ac09c00daf10bc3c4e223b               guano apes   151
# 41  00000c289a1829a808ac09c00daf10bc3c4e223b       the rolling stones   150
# 42  00000c289a1829a808ac09c00daf10bc3c4e223b          little big town   145
# 43  00000c289a1829a808ac09c00daf10bc3c4e223b              team dresch   137
# 44  00000c289a1829a808ac09c00daf10bc3c4e223b                    betty   135
# 45  00000c289a1829a808ac09c00daf10bc3c4e223b                       l7   135
# 46  00000c289a1829a808ac09c00daf10bc3c4e223b                bif naked   134
# 47  00000c289a1829a808ac09c00daf10bc3c4e223b               girlschool   134
# 48  00000c289a1829a808ac09c00daf10bc3c4e223b          the wallflowers   131

# %%
# 유저 수
data['user_id'].nunique()
# Out:
# 358868

# %%
# 아티스트 수
data['artist'].nunique()
# Out:
# 291346

# %%
# 인기 많은 아티스트
artist_count = data.groupby('artist')['user_id'].count()
artist_count.sort_values(ascending=False).head(30)
# Out:
# artist
# radiohead                77254
# the beatles              76245
# coldplay                 66658
# red hot chili peppers    48924
# muse                     46954
# metallica                45233
# pink floyd               44443
# the killers              41229
# linkin park              39773
# nirvana                  39479
# system of a down         37267
# queen                    34174
# u2                       33206
# daft punk                33001
# the cure                 32624
# led zeppelin             32295
# placebo                  32072
# depeche mode             31916
# david bowie              31862
# bob dylan                31799
# death cab for cutie      31482
# arctic monkeys           30348
# foo fighters             30144
# air                      29795
# the rolling stones       29754
# nine inch nails          28946
# sigur rós                28901
# green day                28732
# massive attack           28691
# moby                     28232
# Name: user_id, dtype: int64

# %%
# 유저별 몇 명의 아티스트를 듣고 있는지에 대한 통계
user_count = data.groupby('user_id')['artist'].count()
user_count.describe()
# Out:
# count    358868.000000
# mean         48.863234
# std           8.524272
# min           1.000000
# 25%          46.000000
# 50%          49.000000
# 75%          51.000000
# max         166.000000
# Name: artist, dtype: float64

# %%
# 유저별 play횟수 중앙값에 대한 통계
user_median = data.groupby('user_id')['play'].median()
user_median.describe()
# Out:
# count    358868.000000
# mean        142.187676
# std         213.089902
# min           1.000000
# 25%          32.000000
# 50%          83.000000
# 75%         180.000000
# max       50142.000000
# Name: play, dtype: float64

# %%
# 본인이 좋아하시는 아티스트 데이터로 바꿔서 추가하셔도 됩니다! 단, 이름은 꼭 데이터셋에 있는 것과 동일하게 맞춰주세요.
my_favorite = ['black eyed peas' , 'maroon5' ,'jason mraz' ,'coldplay' ,'beyoncé']

# 'zimin'이라는 user_id가 위 아티스트의 노래를 30회씩 들었다고 가정하겠습니다.
my_playlist = pd.DataFrame({'user_id': ['zimin']*5, 'artist': my_favorite, 'play':[30]*5})

if not data.isin({'user_id':['zimin']})['user_id'].any():  # user_id에 'zimin'이라는 데이터가 없다면
    data = data.append(my_playlist)                           # 위에 임의로 만든 my_favorite 데이터를 추가해 줍니다.

data.tail(10)       # 잘 추가되었는지 확인해 봅시다.
# Out:
#                user_id           artist  play
# 17535650  sep 20, 2008       turbostaat    12
# 17535651  sep 20, 2008    cuba missouri    11
# 17535652  sep 20, 2008  little man tate    11
# 17535653  sep 20, 2008        sigur rós    10
# 17535654  sep 20, 2008       the smiths    10
# 0                zimin  black eyed peas    30
# 1                zimin          maroon5    30
# 2                zimin       jason mraz    30
# 3                zimin         coldplay    30
# 4                zimin          beyoncé    30

# %%
# 고유한 유저, 아티스트를 찾아내는 코드
user_unique = data['user_id'].unique()
artist_unique = data['artist'].unique()

# 유저, 아티스트 indexing 하는 코드 idx는 index의 약자입니다.
user_to_idx = {v:k for k,v in enumerate(user_unique)}
artist_to_idx = {v:k for k,v in enumerate(artist_unique)}

# %%
artist_to_idx
# Out:
# {'betty blowtorch': 0,
#  'die ärzte': 1,
#  'melissa etheridge': 2,
#  'elvenking': 3,
#  'juliette & the licks': 4,
#  'red hot chili peppers': 5,
#  'magica': 6,
#  'the black dahlia murder': 7,
#  'the murmurs': 8,
#  'lunachicks': 9,
#  'walls of jericho': 10,
#  'letzte instanz': 11,
#  'goldfrapp': 12,
#  'horrorpops': 13,
#  'the butchies': 14,
#  'jack off jill': 15,
#  'babes in toyland': 16,
#  'dropkick murphys': 17,
#  'all:my:faults': 18,
#  'le tigre': 19,
#  'schandmaul': 20,
#  'edguy': 21,
#  'maximum the hormone': 22,
#  'all ends': 23,
#  'jack johnson': 24,
#  'eluveitie': 25,
#  'rasputina': 26,
#  'london after midnight': 27,
#  'the killers': 28,
#  'mutyumu': 29,
#  'judas priest': 30,
#  'rob zombie': 31,
#  'the bosshoss': 32,
#  'blue öyster cult': 33,
#  'sandra nasic': 34,
#  'john mayer': 35,
#  'sleater-kinney': 36,
#  'the who': 37,
#  'disciple': 38,
#  'tanzwut': 39,
#  'guano apes': 40,
#  'the rolling stones': 41,
#  'little big town': 42,
#  'team dresch': 43,
#  'betty': 44,
#  'l7': 45,
#  'bif naked': 46,
#  'girlschool': 47,
#  'the wallflowers': 48,
#  'the most serene republic': 49,
#  'stars': 50,
#  'broken social scene': 51,
#  'have heart': 52,
#  'luminous orange': 53,
#  'boris': 54,
#  'arctic monkeys': 55,
#  'bright eyes': 56,
#  'coaltar of the deepers': 57,
#  'polar bear club': 58,
#  'the libertines': 59,
#  'death from above 1979': 60,
#  'owl city': 61,
#  'coldplay': 62,
#  'okkervil river': 63,
#  'jim sturgess': 64,
#  'deerhoof': 65,
#  'fear before the march of flames': 66,
#  'breathe carolina': 67,
#  'mstrkrft': 68,
#  'arcade fire': 69,
#  'the strokes': 70,
#  'cancer bats': 71,
#  'the honorary title': 72,
#  'michio kurihara': 73,
#  'mgmt': 74,
#  'queen': 75,
#  'the secret handshake': 76,
#  'animal collective': 77,
#  'heavy heavy low low': 78,
#  'hot hot heat': 79,
#  'hadouken!': 80,
#  'the wombats': 81,
#  'ai aso': 82,
#  'boris with michio kurihara': 83,
#  'uffie': 84,
#  'the last shadow puppets': 85,
#  'boys noize': 86,
#  'built to spill': 87,
#  'nujabes': 88,
#  'the rocket summer': 89,
#  'little dragon': 90,
#  'boris with merzbow': 91,
#  'the album leaf': 92,
#  'the microphones': 93,
#  'simian mobile disco': 94,
#  'm.i.a.': 95,
#  'death cab for cutie': 96,
#  'patrick wolf': 97,
#  'the fiery furnaces': 98,
#  'digitalism': 99,
#  'current 93': 100,
#  'coil': 101,
#  'andrew liles': 102,
#  'six organs of admittance': 103,
#  '16 horsepower': 104,
#  'angels of light': 105,
#  'the legendary pink dots': 106,
#  'charalambides': 107,
#  'festival': 108,
#  'fern knight': 109,
#  'nick cave & the bad seeds': 110,
#  'fovea hex': 111,
#  'amanda rogers': 112,
#  'lux interna': 113,
#  'nalle': 114,
#  'antony and the johnsons': 115,
#  'marissa nadler': 116,
#  'a silver mt. zion': 117,
#  'einstürzende neubauten': 118,
#  'marc almond': 119,
#  'mariee sioux': 120,
#  'björk': 121,
#  'bill fay': 122,
#  'nurse with wound': 123,
#  'baby dee': 124,
#  'ghq': 125,
#  'daniel higgs': 126,
#  'flairck': 127,
#  'jack rose': 128,
#  'castanets': 129,
#  'john jacob niles': 130,
#  'the revolutionary army of the infant jesus': 131,
#  'carter tutti': 132,
#  'the one ensemble': 133,
#  'orion rigel dommisse': 134,
#  'jocelyn pook': 135,
#  'matmos': 136,
#  'ulver': 137,
#  'ane brun': 138,
#  'soisong': 139,
#  'a hawk and a hacksaw': 140,
#  'frank london': 141,
#  'michael gira': 142,
#  'larkin grimm': 143,
#  'pelt': 144,
#  'jean parlette': 145,
#  'opeth': 146,
#  'cannibal corpse': 147,
#  'elis': 148,
#  'amoral': 149,
#  'amon amarth': 150,
#  'riverside': 151,
#  'dark tranquillity': 152,
#  'atrocity': 153,
#  'kromlek': 154,
#  'kamelot': 155,
#  'novembers doom': 156,
#  'poe': 157,
#  'rock universal': 158,
#  'dido': 159,
#  'stone temple pilots': 160,
#  'audioslave': 161,
#  'katatonia': 162,
#  'ark': 163,
#  'circus maximus': 164,
#  'dimmu borgir': 165,
#  'death': 166,
#  'månegarm': 167,
#  'cynic': 168,
#  'korpiklaani': 169,
#  'my dying bride': 170,
#  'brujeria': 171,
#  'agalloch': 172,
#  'alice in chains': 173,
#  'johann sebastian bach': 174,
#  'kalmah': 175,
#  'farmakon': 176,
#  'children of bodom': 177,
#  'dragonforce': 178,
#  'dredg': 179,
#  'green carnation': 180,
#  'pain of salvation': 181,
#  'rhapsody of fire': 182,
#  'the mars volta': 183,
#  'tool': 184,
#  'arch enemy': 185,
#  'at the gates': 186,
#  'compay segundo': 187,
#  'ensiferum': 188,
#  'naglfar': 189,
#  'nevermore': 190,
#  'old mans child': 191,
#  'shade empire': 192,
#  'system of a down': 193,
#  'tristania': 194,
#  'devendra banhart': 195,
#  'boards of canada': 196,
#  'cocorosie': 197,
#  'aphex twin': 198,
#  'atmosphere': 199,
#  'joanna newsom': 200,
#  'air': 201,
#  'portishead': 202,
#  'massive attack': 203,
#  'plaid': 204,
#  'fog': 205,
#  'prefuse 73': 206,
#  'm83': 207,
#  'the flashbulb': 208,
#  'pavement': 209,
#  'amon tobin': 210,
#  'sage francis': 211,
#  'four tet': 212,
#  'brother ali': 213,
#  'max richter': 214,
#  'why?': 215,
#  'autechre': 216,
#  'radiohead': 217,
#  'susumu yokota': 218,
#  'electrelane': 219,
#  'neutral milk hotel': 220,
#  'bent': 221,
#  'vetiver': 222,
#  'k-the-i???': 223,
#  'illogic': 224,
#  'annie': 225,
#  'broadcast': 226,
#  'beastie boys': 227,
#  'aesop rock': 228,
#  'mf doom': 229,
#  'the books': 230,
#  'bibio': 231,
#  "rachel's": 232,
#  'architecture in helsinki': 233,
#  'bola': 234,
#  'isan': 235,
#  'apes & androids': 236,
#  'múm': 237,
#  'elliott smith': 238,
#  'caribou': 239,
#  'the hold steady': 240,
#  'mogwai': 241,
#  'justice': 242,
#  'sigur rós': 243,
#  'clutch': 244,
#  'white denim': 245,
#  'the go! team': 246,
#  'the beatles': 247,
#  "2 many dj's": 248,
#  'tv on the radio': 249,
#  'kyuss': 250,
#  'dj shadow': 251,
#  'a tribe called quest': 252,
#  'the cinematic orchestra': 253,
#  'beck': 254,
#  'bon iver': 255,
#  'röyksopp': 256,
#  'rex the dog': 257,
#  'bonobo': 258,
#  'deadmau5': 259,
#  'the decemberists': 260,
#  'earth': 261,
#  'snow patrol': 262,
#  'battles': 263,
#  'metronomy': 264,
#  'dj format': 265,
#  'the prodigy': 266,
#  'lemon jelly': 267,
#  'pink floyd': 268,
#  'rjd2': 269,
#  'the flaming lips': 270,
#  'alasdair fraser & paul machlis': 271,
#  'passion pit': 272,
#  'holy fuck': 273,
#  'michael jackson': 274,
#  'late of the pier': 275,
#  'flight of the conchords': 276,
#  'muse': 277,
#  'fleetwood mac': 278,
#  'led zeppelin': 279,
#  'stam1na': 280,
#  'dream theater': 281,
#  'ac/dc': 282,
#  'metallica': 283,
#  'iron maiden': 284,
#  'bob marley & the wailers': 285,
#  'megadeth': 286,
#  'trivium': 287,
#  'raappana': 288,
#  'nightwish': 289,
#  'kotiteollisuus': 290,
#  'sublime': 291,
#  'viikate': 292,
#  'volbeat': 293,
#  "guns n' roses": 294,
#  'bon jovi': 295,
#  'dio': 296,
#  'soldiers of jah army': 297,
#  'scorpions': 298,
#  'teräsbetoni': 299,
#  'nopsajalka': 300,
#  'paramore': 301,
#  'the darkness': 302,
#  'soul captain band': 303,
#  'asa': 304,
#  'tarot': 305,
#  'klamydia': 306,
#  'gentleman': 307,
#  'mötley crüe': 308,
#  'manowar': 309,
#  'killswitch engage': 310,
#  'slayer': 311,
#  'in flames': 312,
#  'skid row': 313,
#  'stone': 314,
#  'bullet for my valentine': 315,
#  'mokoma': 316,
#  'pantera': 317,
#  'brother firetribe': 318,
#  'hurriganes': 319,
#  'norther': 320,
#  'stratovarius': 321,
#  'kiuas': 322,
#  'ozzy osbourne': 323,
#  'pin': 324,
#  'feel': 325,
#  'elton john': 326,
#  'orgy': 327,
#  'brandy': 328,
#  'pet shop boys': 329,
#  'sade': 330,
#  'belinda carlisle': 331,
#  'eurythmics': 332,
#  'mike oldfield': 333,
#  'hall & oates': 334,
#  'chris rea': 335,
#  'laura branigan': 336,
#  'the waterboys': 337,
#  'maciej silski': 338,
#  'leona lewis': 339,
#  'george michael': 340,
#  'black': 341,
#  'frozen silence': 342,
#  'sweet coffee': 343,
#  'blackfield': 344,
#  'cyndi lauper': 345,
#  'pseudo echo': 346,
#  'desireless': 347,
#  'limp bizkit': 348,
#  'modern talking': 349,
#  'rihanna': 350,
#  'a-ha': 351,
#  'linkin park': 352,
#  'hans zimmer': 353,
#  'nelly furtado': 354,
#  'madonna': 355,
#  'blink-182': 356,
#  'dave gahan': 357,
#  'kelly clarkson': 358,
#  'lucie silvas': 359,
#  'natalie imbruglia': 360,
#  'michelle branch': 361,
#  'delta goodrem': 362,
#  'new order': 363,
#  'seal': 364,
#  'atomic kitten': 365,
#  'backstreet boys': 366,
#  'mary j. blige': 367,
#  'negative': 368,
#  'justin timberlake': 369,
#  'savage garden': 370,
#  'nerina pallot': 371,
#  'erasure': 372,
#  'culture club': 373,
#  'mr. oizo': 374,
#  'robbie williams': 375,
#  'black eyed peas': 376,
#  'antonio orozco': 377,
#  'decai': 378,
#  'kiko & shara': 379,
#  'marc anthony': 380,
#  'manuel carrasco': 381,
#  'mika': 382,
#  'juanes': 383,
#  'la oreja de van gogh': 384,
#  'melendi': 385,
#  'amaral': 386,
#  'andy & lucas': 387,
#  'chambao': 388,
#  'chayanne': 389,
#  'christian castro': 390,
#  'christina aguilera': 391,
#  'craig david': 392,
#  'luis fonsi': 393,
#  'sergio contreras': 394,
#  'ana torroja': 395,
#  'beyoncé': 396,
#  'bustamante': 397,
#  'camila': 398,
#  'colbie caillat': 399,
#  'coti': 400,
#  'david bisbal': 401,
#  'edurne': 402,
#  'fito & fitipaldis': 403,
#  'hanna': 404,
#  'malu': 405,
#  'paulina rubio': 406,
#  'rosana': 407,
#  't.a.t.u.': 408,
#  'amy winehouse': 409,
#  'efecto mariposa': 410,
#  'el arrebato': 411,
#  'enrique iglesias': 412,
#  'fondo flamenco': 413,
#  'jennifer lopez': 414,
#  'mecano': 415,
#  'phil collins': 416,
#  'sean kingston': 417,
#  'u2': 418,
#  'dub fx': 419,
#  'box car racer': 420,
#  'zebrahead': 421,
#  'paul oakenfold': 422,
#  'pendulum': 423,
#  'ronald jenkees': 424,
#  'sum 41': 425,
#  'angels & airwaves': 426,
#  'haggard': 427,
#  'alien ant farm': 428,
#  'the offspring': 429,
#  'океан ельзи': 430,
#  'ronan hardiman': 431,
#  'the crystal method': 432,
#  '川田まみ': 433,
#  'eminem': 434,
#  'the qemists': 435,
#  'silverstein': 436,
#  'rise against': 437,
#  'бумбокс': 438,
#  'scum of the earth': 439,
#  'blu mar ten': 440,
#  'bomfunk mcs': 441,
#  'vanessa-mae': 442,
#  'тартак': 443,
#  'drop dead, gorgeous': 444,
#  'flying steps': 445,
#  'drumattic twins': 446,
#  'andrew w.k.': 447,
#  'hoobastank': 448,
#  'dover': 449,
#  'bodyjar': 450,
#  'southside rockers': 451,
#  'prodigy': 452,
#  'future prophecies': 453,
#  'jonathan coulton': 454,
#  'blessthefall': 455,
#  'nubreed & luke chable': 456,
#  'franz ferdinand': 457,
#  'johannes linstead': 458,
#  'infected mushroom': 459,
#  'darude': 460,
#  'akira yamaoka': 461,
#  'aqua': 462,
#  'clawfinger': 463,
#  'dusty kid': 464,
#  'senses fail': 465,
#  'commix': 466,
#  'id software': 467,
#  'panic at the disco': 468,
#  'enigma': 469,
#  'fatboy slim': 470,
#  'krs-one': 471,
#  'drowning pool': 472,
#  'placebo': 473,
#  'david & the citizens': 474,
#  'kent': 475,
#  'säkert!': 476,
#  'detektivbyrån': 477,
#  'lars winnerbäck': 478,
#  'raymond & maria': 479,
#  'tegan and sara': 480,
#  'the knife': 481,
#  'tiger lou': 482,
#  'håkan hellström': 483,
#  'david fridlund': 484,
#  'the ark': 485,
#  'alice in videoland': 486,
#  'timo räisänen': 487,
#  'the cardigans': 488,
#  'bloc party': 489,
#  'oasis': 490,
#  'sahara hotnights': 491,
#  'vapnet': 492,
#  'laleh': 493,
#  'markus krunegård': 494,
#  'the kooks': 495,
#  'deportees': 496,
#  'r.e.m.': 497,
#  'slagsmålsklubben': 498,
#  'hot chip': 499,
#  'millencolin': 500,
#  'the sounds': 501,
#  'mew': 502,
#  'green day': 503,
#  'kings of convenience': 504,
#  'firefox ak': 505,
#  'mando diao': 506,
#  'the tough alliance': 507,
#  'shout out louds': 508,
#  'keane': 509,
#  'wir sind helden': 510,
#  'thompson twins': 511,
#  'hanson': 512,
#  'no doubt': 513,
#  'orchestral manoeuvres in the dark': 514,
#  'the human league': 515,
#  'altered images': 516,
#  'martina mcbride': 517,
#  'yazoo': 518,
#  'regina spektor': 519,
#  'the format': 520,
#  'carolyn dawn johnson': 521,
#  'mazzy star': 522,
#  'dashboard confessional': 523,
#  'jonathan larson': 524,
#  'wicked': 525,
#  'the verve pipe': 526,
#  'missing persons': 527,
#  'the passions': 528,
#  'ima robot': 529,
#  'judith holofernes': 530,
#  'depeche mode': 531,
#  'fake': 532,
#  'der plan': 533,
#  'gwen stefani': 534,
#  'dierks bentley': 535,
#  'heaven 17': 536,
#  'the sundays': 537,
#  'dixie chicks': 538,
#  'shania twain': 539,
#  'stacey q': 540,
#  'camera obscura': 541,
#  'deana carter': 542,
#  'matt & kim': 543,
#  'steel train': 544,
#  'dan fogelberg': 545,
#  'taking back sunday': 546,
#  'andrew bird': 547,
#  'jewel': 548,
#  'haircut 100': 549,
#  'britney spears': 550,
#  'kristy lee': 551,
#  'the police': 552,
#  'the postal service': 553,
#  'fefe dobson': 554,
#  'julie roberts': 555,
#  'j dilla': 556,
#  'nas': 557,
#  'common': 558,
#  'black milk': 559,
#  'pete rock': 560,
#  'jay-z': 561,
#  'dr. dre': 562,
#  'evidence': 563,
#  'kanye west': 564,
#  'dead prez': 565,
#  'percee p': 566,
#  'jeff mills': 567,
#  'method man': 568,
#  'panacea': 569,
#  '2pac': 570,
#  'fort minor': 571,
#  'madvillain': 572,
#  'ratatat': 573,
#  'talib kweli': 574,
#  'do or die': 575,
#  'madlib': 576,
#  '50 cent': 577,
#  'abstract rude & tribe unique': 578,
#  'the alchemist': 579,
#  'bill evans': 580,
#  'gza/genius': 581,
#  'lil wayne': 582,
#  'styles p': 583,
#  'emc': 584,
#  'ghostface': 585,
#  'k-os': 586,
#  'burial': 587,
#  'dj vadim': 588,
#  'el-p': 589,
#  'big shug': 590,
#  'black spade': 591,
#  'john coltrane': 592,
#  'the residents': 593,
#  'roni size & reprazent': 594,
#  'flying lotus - (www.influencias-urbanas.blogspot.com)': 595,
#  'the cool kids': 596,
#  'the game': 597,
#  'redman': 598,
#  'rza': 599,
#  'joan baez': 600,
#  'e-rotic': 601,
#  'goo goo dolls': 602,
#  'apulanta': 603,
#  'chorale': 604,
#  'bryan adams': 605,
#  'gnarls barkley': 606,
#  'groove coverage': 607,
#  'september': 608,
#  '3 doors down': 609,
#  'basic element': 610,
#  'chris brown': 611,
#  'eels': 612,
#  'solid base': 613,
#  'irwin goodman': 614,
#  'moby': 615,
#  'don huonot': 616,
#  'stella': 617,
#  'the pussycat dolls': 618,
#  'cascada': 619,
#  'john legend': 620,
#  'alicia keys': 621,
#  'kapasiteettiyksikkö': 622,
#  'sonata arctica': 623,
#  'frank sinatra': 624,
#  'jonas brothers': 625,
#  'deep insight': 626,
#  'maroon 5': 627,
#  'the calling': 628,
#  'ambassadöör': 629,
#  'cheek': 630,
#  'darin': 631,
#  'antti tuisku': 632,
#  'usher': 633,
#  'finlanders': 634,
#  'sadetanssi': 635,
#  'snoop dogg': 636,
#  'akon': 637,
#  'mamba': 638,
#  'da buzz': 639,
#  'jessy': 640,
#  'syd barrett': 641,
#  'spiritualized': 642,
#  'the boo radleys': 643,
#  'the brian jonestown massacre': 644,
#  'black rebel motorcycle club': 645,
#  'the duke spirit': 646,
#  'the stone roses': 647,
#  'jefferson airplane': 648,
#  'the black angels': 649,
#  'graham bond organisation': 650,
#  'love': 651,
#  'the warlocks': 652,
#  'a place to bury strangers': 653,
#  'not from there': 654,
#  'richard in your mind': 655,
#  'king khan & the shrines': 656,
#  'the stairs': 657,
#  'the vera violets': 658,
#  "edgar 'jones' jones": 659,
#  'film school': 660,
#  'captain beefheart & his magic band': 661,
#  'the charlatans': 662,
#  'kaleidoscope': 663,
#  'the raconteurs': 664,
#  'dungen': 665,
#  'the velvet underground': 666,
#  'spindrift': 667,
#  'the incredible string band': 668,
#  'flavor crystals': 669,
#  'nico': 670,
#  'the dandy warhols': 671,
#  'asobi seksu': 672,
#  'stereolab': 673,
#  'fairport convention': 674,
#  'nick drake': 675,
#  'soft machine': 676,
#  'the greenhornes': 677,
#  'the national': 678,
#  'black mountain': 679,
#  'television': 680,
#  'the telescopes': 681,
#  'lostprophets': 682,
#  'all time low': 683,
#  'lucky boys confusion': 684,
#  'amber pacific': 685,
#  'four year strong': 686,
#  'fall out boy': 687,
#  'the weakerthans': 688,
#  'showoff': 689,
#  '+44': 690,
#  'damien rice': 691,
#  'my chemical romance': 692,
#  'ben kweller': 693,
#  'foo fighters': 694,
#  'anberlin': 695,
#  'moving mountains': 696,
#  'the wedding': 697,
#  'frightened rabbit': 698,
#  'cartel': 699,
#  'saosin': 700,
#  'set your goals': 701,
#  'holiday parade': 702,
#  'cauterize': 703,
#  'nizlopi': 704,
#  'hit the lights': 705,
#  'get cape. wear cape. fly': 706,
#  'better luck next time': 707,
#  'girl talk': 708,
#  'story of the year': 709,
#  'joshua radin': 710,
#  'the frantic': 711,
#  'the ataris': 712,
#  'sufjan stevens': 713,
#  'sherwood': 714,
#  'norah jones': 715,
#  'madredeus': 716,
#  'așa': 717,
#  'carla bruni': 718,
#  'penguin cafe orchestra': 719,
#  'ravid goldschmidt': 720,
#  'humanos': 721,
#  'xutos & pontapés': 722,
#  'paul simon': 723,
#  'lily allen': 724,
#  'kid loco': 725,
#  'pedro abrunhosa': 726,
#  'stevie wonder': 727,
#  'thievery corporation': 728,
#  'the streets': 729,
#  'ratos de porão': 730,
#  'lady sovereign': 731,
#  'faith no more': 732,
#  'manu chao': 733,
#  'tenacious d': 734,
#  'fantômas': 735,
#  'type o negative': 736,
#  'pearl jam': 737,
#  'cali lewis': 738,
#  'the commitments': 739,
#  'soundgarden': 740,
#  'buckethead': 741,
#  'the cult': 742,
#  'rush': 743,
#  'king crimson': 744,
#  'camel': 745,
#  'amplifier': 746,
#  'uriah heep': 747,
#  'the answer': 748,
#  'yes': 749,
#  'disturbed': 750,
#  'jethro tull': 751,
#  'porcupine tree': 752,
#  'liquid tension experiment': 753,
#  'ted nugent': 754,
#  'wolfmother': 755,
#  'emerson, lake & palmer': 756,
#  'aerosmith': 757,
#  'iommi': 758,
#  'frankie goes to hollywood': 759,
#  'ufo': 760,
#  'days of the new': 761,
#  'caravan': 762,
#  'the verve': 763,
#  'rammstein': 764,
#  'wishbone ash': 765,
#  'the moody blues': 766,
#  'jordan rudess': 767,
#  'chevelle': 768,
#  'cream': 769,
#  'patti smith': 770,
#  'nickelback': 771,
#  'zz top': 772,
#  'nine inch nails': 773,
#  'my bloody valentine': 774,
#  'pj harvey': 775,
#  'the cure': 776,
#  'nick cave and the bad seeds': 777,
#  'the jesus and mary chain': 778,
#  'the sisters of mercy': 779,
#  'david bowie': 780,
#  'a perfect circle': 781,
#  'the white stripes': 782,
#  'the dresden dolls': 783,
#  'nouvelle vague': 784,
#  'leonard cohen': 785,
#  'rowland s. howard': 786,
#  'creedence clearwater revival': 787,
#  'goon moon': 788,
#  'grinderman': 789,
#  'gary numan': 790,
#  'slowdive': 791,
#  'the boys next door': 792,
#  'beirut': 793,
#  'joy division': 794,
#  'clint mansell': 795,
#  'inkubus sukkubus': 796,
#  'the smiths': 797,
#  'cat power': 798,
#  'nick cave & warren ellis': 799,
#  'anita lane': 800,
#  'bauhaus': 801,
#  'amiina': 802,
#  'bajaga': 803,
#  'interpol': 804,
#  'the 69 eyes': 805,
#  'christian death': 806,
#  'the stooges': 807,
#  'iggy pop': 808,
#  'grave digger': 809,
#  'running wild': 810,
#  'primal fear': 811,
#  'paragon': 812,
#  'iced earth': 813,
#  'lamb of god': 814,
#  'u.d.o.': 815,
#  'annihilator': 816,
#  'exodus': 817,
#  'exciter': 818,
#  'strapping young lad': 819,
#  'kreator': 820,
#  'rebellion': 821,
#  'sabaton': 822,
#  'helloween': 823,
#  'iron savior': 824,
#  'accept': 825,
#  '3 inches of blood': 826,
#  'jag panzer': 827,
#  'mastodon': 828,
#  'steel attack': 829,
#  'daath': 830,
#  'metal church': 831,
#  'gojira': 832,
#  'devildriver': 833,
#  'decapitated': 834,
#  'hammerfall': 835,
#  'the ocean': 836,
#  'hatebreed': 837,
#  'mortification': 838,
#  'halford': 839,
#  'meshuggah': 840,
#  'finntroll': 841,
#  'gamma ray': 842,
#  'stormwarrior': 843,
#  'fight': 844,
#  'vicious rumors': 845,
#  'dream evil': 846,
#  'necrophagist': 847,
#  'rage': 848,
#  'morgana lefay': 849,
#  'chiodos': 850,
#  'black tequila': 851,
#  '30 seconds to mars': 852,
#  'as i lay dying': 853,
#  'a static lullaby': 854,
#  'billy talent': 855,
#  'bosse': 856,
#  'deus': 857,
#  'feeder': 858,
#  'funeral for a friend': 859,
#  'a day to remember': 860,
#  'beatsteaks': 861,
#  'coheed and cambria': 862,
#  'dúné': 863,
#  'enter shikari': 864,
#  'finch': 865,
#  'from first to last': 866,
#  'lostalone': 867,
#  'mindless self indulgence': 868,
#  'olli schulz & der hund marie': 869,
#  'slut': 870,
#  'the dreaming': 871,
#  'alesana': 872,
#  'ash': 873,
#  'brand new': 874,
#  'canoe': 875,
#  'kill hannah': 876,
#  'madsen': 877,
#  'maxïmo park': 878,
#  'neaera': 879,
#  'scary kids scaring kids': 880,
#  'secret and whisper': 881,
#  'the fall of troy': 882,
#  'the vines': 883,
#  'virginia jetzt!': 884,
#  'as we fight': 885,
#  'grammatics': 886,
#  'tele': 887,
#  'underoath': 888,
#  'parragon books': 889,
#  'michael armstrong': 890,
#  'alkaline trio': 891,
#  'afi': 892,
#  'tiger army': 893,
#  'elvis costello': 894,
#  'elvis presley': 895,
#  'the mighty mighty bosstones': 896,
#  'adema': 897,
#  'foghat': 898,
#  'kylie minogue': 899,
#  'foxboro hot tubs': 900,
#  'pink': 901,
#  'tim mcgraw': 902,
#  'dead to me': 903,
#  'mxpx': 904,
#  'bad religion': 905,
#  'jimmy eat world': 906,
#  'the gaslight anthem': 907,
#  'danny elfman': 908,
#  'dead kennedys': 909,
#  'nirvana': 910,
#  'the tantra monsters': 911,
#  'poison': 912,
#  'me first and the gimme gimmes': 913,
#  'mgm studio orchestra': 914,
#  'new found glory': 915,
#  'agnostic front': 916,
#  'all': 917,
#  'marilyn manson': 918,
#  'rancid': 919,
#  'less than jake': 920,
#  'my life with the thrill kill kult': 921,
#  'the aquabats': 922,
#  'the distillers': 923,
#  'skarface': 924,
#  'mad caddies': 925,
#  'nofx': 926,
#  'cypress hill': 927,
#  'koяn': 928,
#  'the planet smashers': 929,
#  'reel big fish': 930,
#  'ska-p': 931,
#  'moskovskaya': 932,
#  'onyx': 933,
#  'belvedere': 934,
#  'distemper': 935,
#  'aventura': 936,
#  "5'nizza": 937,
#  'captain everything!': 938,
#  'bob marley': 939,
#  'slipknot': 940,
#  'alizée': 941,
#  'electrosoul system': 942,
#  'richard cheese': 943,
#  'avril lavigne': 944,
#  'otklonenie': 945,
#  'cidade negra': 946,
#  'talco': 947,
#  'f.p.g.': 948,
#  'the specials': 949,
#  'daddy yankee': 950,
#  'skaface': 951,
#  'tina charles': 952,
#  'yeah yeah yeahs': 953,
#  'the dead weather': 954,
#  'no age': 955,
#  'tiny masters of today': 956,
#  'japandroids': 957,
#  'the used': 958,
#  'veto': 959,
#  'friendly fires': 960,
#  'hateen': 961,
#  'onerepublic': 962,
#  'dead fish': 963,
#  'sixpence none the richer': 964,
#  'peter bjorn and john': 965,
#  'thursday': 966,
#  'weezer': 967,
#  'japanther': 968,
#  'kings of leon': 969,
#  "rock'n'zombie": 970,
#  'feist': 971,
#  'klaxons': 972,
#  'cansei de ser sexy': 973,
#  'does it offend you, yeah?': 974,
#  'twilight': 975,
#  'grease': 976,
#  'kaiser chiefs': 977,
#  'pelle miljoona': 978,
#  'ripsipiirakka': 979,
#  'orson': 980,
#  'frankie valli': 981,
#  'motion city soundtrack': 982,
#  'kuningas pähkinä & setä tamu': 983,
#  'genesis': 984,
#  'jukka poika': 985,
#  'technotronic': 986,
#  'robert pattinson': 987,
#  'stig dogg': 988,
#  'aviation': 989,
#  'high school musical 2': 990,
#  'kapteeni ä-ni': 991,
#  'ramones': 992,
#  'fools garden': 993,
#  'bone thugs-n-harmony': 994,
#  'rufus wainwright': 995,
#  'iron & wine': 996,
#  'blue foundation': 997,
#  'lemon ice': 998,
#  'the black ghosts': 999,
#  ...}

# %%
# 인덱싱이 잘 되었는지 확인해 봅니다.
print(user_to_idx['zimin'])    # 358869명의 유저 중 마지막으로 추가된 유저이니 358868이 나와야 합니다.
print(artist_to_idx['black eyed peas'])
# Out:
# 358868
# 376

# %%
# indexing을 통해 데이터 컬럼 내 값을 바꾸는 코드
# dictionary 자료형의 get 함수는 https://wikidocs.net/16 을 참고하세요.

# user_to_idx.get을 통해 user_id 컬럼의 모든 값을 인덱싱한 Series를 구해 봅시다.
# 혹시 정상적으로 인덱싱되지 않은 row가 있다면 인덱스가 NaN이 될 테니 dropna()로 제거합니다.
temp_user_data = data['user_id'].map(user_to_idx.get).dropna()
if len(temp_user_data) == len(data):   # 모든 row가 정상적으로 인덱싱되었다면
    print('user_id column indexing OK!!')
    data['user_id'] = temp_user_data   # data['user_id']을 인덱싱된 Series로 교체해 줍니다.
else:
    print('user_id column indexing Fail!!')

# artist_to_idx을 통해 artist 컬럼도 동일한 방식으로 인덱싱해 줍니다.
temp_artist_data = data['artist'].map(artist_to_idx.get).dropna()
if len(temp_artist_data) == len(data):
    print('artist column indexing OK!!')
    data['artist'] = temp_artist_data
else:
    print('artist column indexing Fail!!')

data
# Out:
# user_id column indexing OK!!
# artist column indexing OK!!
#     user_id  artist  play
# 0         0       0  2137
# 1         0       1  1099
# 2         0       2   897
# 3         0       3   717
# 4         0       4   706
# ..      ...     ...   ...
# 0    358868     376    30
# 1    358868  270115    30
# 2    358868    3746    30
# 3    358868      62    30
# 4    358868     396    30
#
# [17535660 rows x 3 columns]

# %%
# 1회만 play한 데이터의 비율을 보는 코드
only_one = data[data['play']<2]
one, all_data = len(only_one), len(data)
print(f'{one},{all_data}')
print(f'Ratio of only_one over all data is {one/all_data:.2%}')  # f-format에 대한 설명은 https://bit.ly/2DTLqYU
# Out:
# 147740,17535660
# Ratio of only_one over all data is 0.84%

# %%
# 실습 위에 설명보고 이해해서 만들어보기
from scipy.sparse import csr_matrix

num_user = data['user_id'].nunique()
num_artist = data['artist'].nunique()

csr_data = csr_matrix((data.play, (data.user_id, data.artist)), shape= (num_user, num_artist))
csr_data
# Out:
# <358869x291347 sparse matrix of type '<class 'numpy.longlong'>'
# 	with 17535578 stored elements in Compressed Sparse Row format>

# %%
from implicit.als import AlternatingLeastSquares
import os
import numpy as np

# implicit 라이브러리에서 권장하고 있는 부분입니다. 학습 내용과는 무관합니다.
os.environ['OPENBLAS_NUM_THREADS']='1'
os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ['MKL_NUM_THREADS']='1'

# %%
# Implicit AlternatingLeastSquares 모델의 선언
als_model = AlternatingLeastSquares(factors=100, regularization=0.01, use_gpu=False, iterations=15, dtype=np.float32)

# %%
# als 모델은 input으로 (item X user 꼴의 matrix를 받기 때문에 Transpose해줍니다.)
csr_data_transpose = csr_data.T
csr_data_transpose
# Out:
# <291347x358869 sparse matrix of type '<class 'numpy.longlong'>'
# 	with 17535578 stored elements in Compressed Sparse Column format>

# %%
# 모델 훈련
als_model.fit(csr_data_transpose)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
zimin, black_eyed_peas = user_to_idx['zimin'], artist_to_idx['black eyed peas']
zimin_vector, black_eyed_peas_vector = als_model.user_factors[zimin], als_model.item_factors[black_eyed_peas]

print('슝=3')
# Out:
# 슝=3

# %%
zimin_vector
# Out:
# array([-0.63287926, -0.17096472,  0.75971884,  0.71137196, -0.8993717 ,
#         0.44279796,  0.26255837, -0.58014745, -0.5519371 ,  0.42080978,
#        -1.1145458 , -0.16201554,  0.7488859 ,  0.62646884,  0.19524127,
#         0.23955984, -0.29442292,  1.2096434 , -0.60218054, -0.19713716,
#        -0.39693928,  0.6547616 , -1.2106874 , -0.43096688,  0.08094504,
#        -1.1795393 ,  0.2753424 ,  0.23342296,  0.8210413 , -0.25944284,
#        -0.4912829 , -1.0513059 ,  0.28743818, -0.6498186 ,  1.4841862 ,
#         0.42408413,  0.50169486, -0.2156885 ,  0.90303576,  0.6626202 ,
#        -0.15246119,  0.28514758, -0.0217981 ,  0.20220117,  0.38257363,
#        -0.23078617, -0.7268144 , -0.7628062 , -0.74450284,  0.3942481 ,
#         0.9207793 , -0.16377915, -0.25160426, -0.6866443 , -0.8297929 ,
#         0.5459524 , -1.0161684 , -0.20445316, -0.45394456,  0.76743305,
#        -0.7920679 , -0.78278047,  1.2730931 , -0.87079656,  0.12571518,
#         0.05947746,  1.460705  ,  0.07976662,  0.2299614 ,  0.17827941,
#         0.34876946,  0.54878515, -0.49093312,  0.72083265,  0.4090281 ,
#        -0.62986815, -0.43102437,  0.03249907,  0.3558003 ,  0.77058667,
#         0.4967588 ,  0.9680622 ,  0.04898885, -0.75912356, -1.4273043 ,
#        -0.16077198,  0.94330627,  0.25291866,  0.40799707,  0.5028934 ,
#         0.5108154 ,  0.5084539 , -0.7549098 , -0.8331368 ,  0.6394937 ,
#         0.7683201 , -0.6181866 ,  0.04297417,  0.08952093,  0.89474195],
#       dtype=float32)

# %%
black_eyed_peas_vector
# Out:
# array([ 0.00770398,  0.01617155,  0.03010621,  0.01973846,  0.00266862,
#         0.00777735,  0.0105153 , -0.02284208,  0.0022515 ,  0.00913543,
#        -0.01110856,  0.00813344,  0.01483378,  0.02087614, -0.00171407,
#        -0.00185388, -0.0004636 ,  0.02020399,  0.00883848,  0.00642998,
#         0.00110257,  0.01159048, -0.00342513,  0.01820252,  0.01713843,
#         0.00038015,  0.00310865,  0.00388653,  0.02297393,  0.00471011,
#        -0.01094565,  0.00132922, -0.00251143,  0.00209996,  0.02336579,
#         0.01390348,  0.01037403, -0.01312966,  0.01647039,  0.01458646,
#         0.00138402,  0.01172214,  0.01257651,  0.0210287 ,  0.01039121,
#         0.00420962, -0.00506149, -0.01031987, -0.00069029, -0.00495903,
#         0.03531162, -0.00590339, -0.01366583,  0.01065554, -0.00660812,
#         0.00797213,  0.0064869 , -0.00034053, -0.00513502,  0.01656103,
#        -0.00099972, -0.00155972,  0.0135981 , -0.0162253 ,  0.01504046,
#         0.02124414,  0.01514345,  0.00402791,  0.00628075,  0.00898748,
#         0.02067879, -0.0011188 ,  0.00598375,  0.00583814,  0.01538681,
#        -0.00927367, -0.01216278,  0.01404887,  0.01340521,  0.00660298,
#         0.01803908,  0.00809578,  0.0122171 , -0.00220494, -0.01081003,
#         0.00207023,  0.00598508,  0.01170278,  0.02076483,  0.02653603,
#         0.01985696,  0.01249111,  0.00324856, -0.00499434,  0.01162085,
#         0.00548385,  0.00507944,  0.00796079,  0.0019917 ,  0.04034091],
#       dtype=float32)

# %%
# zimin과 black_eyed_peas를 내적하는 코드
np.dot(zimin_vector, black_eyed_peas_vector)
# Out:
# 0.49397734

# %%
queen = artist_to_idx['queen']
queen_vector = als_model.item_factors[queen]
np.dot(zimin_vector, queen_vector)
# Out:
# 0.2894393

# %%
favorite_artist = 'coldplay'
artist_id = artist_to_idx[favorite_artist]
similar_artist = als_model.similar_items(artist_id, N=15)
similar_artist
# Out:
# [(62, 0.99999994),
#  (28, 0.98324144),
#  (277, 0.982667),
#  (5, 0.9774035),
#  (490, 0.975333),
#  (217, 0.96521956),
#  (473, 0.9635414),
#  (418, 0.9621225),
#  (247, 0.95925474),
#  (55, 0.94866043),
#  (694, 0.94459677),
#  (910, 0.93837106),
#  (782, 0.93525183),
#  (1018, 0.92755145),
#  (268, 0.92708474)]

# %%
#artist_to_idx 를 뒤집어, index로부터 artist 이름을 얻는 dict를 생성합니다.
idx_to_artist = {v:k for k,v in artist_to_idx.items()}
[idx_to_artist[i[0]] for i in similar_artist]
idx_to_artist
# Out:
# {0: 'betty blowtorch',
#  1: 'die ärzte',
#  2: 'melissa etheridge',
#  3: 'elvenking',
#  4: 'juliette & the licks',
#  5: 'red hot chili peppers',
#  6: 'magica',
#  7: 'the black dahlia murder',
#  8: 'the murmurs',
#  9: 'lunachicks',
#  10: 'walls of jericho',
#  11: 'letzte instanz',
#  12: 'goldfrapp',
#  13: 'horrorpops',
#  14: 'the butchies',
#  15: 'jack off jill',
#  16: 'babes in toyland',
#  17: 'dropkick murphys',
#  18: 'all:my:faults',
#  19: 'le tigre',
#  20: 'schandmaul',
#  21: 'edguy',
#  22: 'maximum the hormone',
#  23: 'all ends',
#  24: 'jack johnson',
#  25: 'eluveitie',
#  26: 'rasputina',
#  27: 'london after midnight',
#  28: 'the killers',
#  29: 'mutyumu',
#  30: 'judas priest',
#  31: 'rob zombie',
#  32: 'the bosshoss',
#  33: 'blue öyster cult',
#  34: 'sandra nasic',
#  35: 'john mayer',
#  36: 'sleater-kinney',
#  37: 'the who',
#  38: 'disciple',
#  39: 'tanzwut',
#  40: 'guano apes',
#  41: 'the rolling stones',
#  42: 'little big town',
#  43: 'team dresch',
#  44: 'betty',
#  45: 'l7',
#  46: 'bif naked',
#  47: 'girlschool',
#  48: 'the wallflowers',
#  49: 'the most serene republic',
#  50: 'stars',
#  51: 'broken social scene',
#  52: 'have heart',
#  53: 'luminous orange',
#  54: 'boris',
#  55: 'arctic monkeys',
#  56: 'bright eyes',
#  57: 'coaltar of the deepers',
#  58: 'polar bear club',
#  59: 'the libertines',
#  60: 'death from above 1979',
#  61: 'owl city',
#  62: 'coldplay',
#  63: 'okkervil river',
#  64: 'jim sturgess',
#  65: 'deerhoof',
#  66: 'fear before the march of flames',
#  67: 'breathe carolina',
#  68: 'mstrkrft',
#  69: 'arcade fire',
#  70: 'the strokes',
#  71: 'cancer bats',
#  72: 'the honorary title',
#  73: 'michio kurihara',
#  74: 'mgmt',
#  75: 'queen',
#  76: 'the secret handshake',
#  77: 'animal collective',
#  78: 'heavy heavy low low',
#  79: 'hot hot heat',
#  80: 'hadouken!',
#  81: 'the wombats',
#  82: 'ai aso',
#  83: 'boris with michio kurihara',
#  84: 'uffie',
#  85: 'the last shadow puppets',
#  86: 'boys noize',
#  87: 'built to spill',
#  88: 'nujabes',
#  89: 'the rocket summer',
#  90: 'little dragon',
#  91: 'boris with merzbow',
#  92: 'the album leaf',
#  93: 'the microphones',
#  94: 'simian mobile disco',
#  95: 'm.i.a.',
#  96: 'death cab for cutie',
#  97: 'patrick wolf',
#  98: 'the fiery furnaces',
#  99: 'digitalism',
#  100: 'current 93',
#  101: 'coil',
#  102: 'andrew liles',
#  103: 'six organs of admittance',
#  104: '16 horsepower',
#  105: 'angels of light',
#  106: 'the legendary pink dots',
#  107: 'charalambides',
#  108: 'festival',
#  109: 'fern knight',
#  110: 'nick cave & the bad seeds',
#  111: 'fovea hex',
#  112: 'amanda rogers',
#  113: 'lux interna',
#  114: 'nalle',
#  115: 'antony and the johnsons',
#  116: 'marissa nadler',
#  117: 'a silver mt. zion',
#  118: 'einstürzende neubauten',
#  119: 'marc almond',
#  120: 'mariee sioux',
#  121: 'björk',
#  122: 'bill fay',
#  123: 'nurse with wound',
#  124: 'baby dee',
#  125: 'ghq',
#  126: 'daniel higgs',
#  127: 'flairck',
#  128: 'jack rose',
#  129: 'castanets',
#  130: 'john jacob niles',
#  131: 'the revolutionary army of the infant jesus',
#  132: 'carter tutti',
#  133: 'the one ensemble',
#  134: 'orion rigel dommisse',
#  135: 'jocelyn pook',
#  136: 'matmos',
#  137: 'ulver',
#  138: 'ane brun',
#  139: 'soisong',
#  140: 'a hawk and a hacksaw',
#  141: 'frank london',
#  142: 'michael gira',
#  143: 'larkin grimm',
#  144: 'pelt',
#  145: 'jean parlette',
#  146: 'opeth',
#  147: 'cannibal corpse',
#  148: 'elis',
#  149: 'amoral',
#  150: 'amon amarth',
#  151: 'riverside',
#  152: 'dark tranquillity',
#  153: 'atrocity',
#  154: 'kromlek',
#  155: 'kamelot',
#  156: 'novembers doom',
#  157: 'poe',
#  158: 'rock universal',
#  159: 'dido',
#  160: 'stone temple pilots',
#  161: 'audioslave',
#  162: 'katatonia',
#  163: 'ark',
#  164: 'circus maximus',
#  165: 'dimmu borgir',
#  166: 'death',
#  167: 'månegarm',
#  168: 'cynic',
#  169: 'korpiklaani',
#  170: 'my dying bride',
#  171: 'brujeria',
#  172: 'agalloch',
#  173: 'alice in chains',
#  174: 'johann sebastian bach',
#  175: 'kalmah',
#  176: 'farmakon',
#  177: 'children of bodom',
#  178: 'dragonforce',
#  179: 'dredg',
#  180: 'green carnation',
#  181: 'pain of salvation',
#  182: 'rhapsody of fire',
#  183: 'the mars volta',
#  184: 'tool',
#  185: 'arch enemy',
#  186: 'at the gates',
#  187: 'compay segundo',
#  188: 'ensiferum',
#  189: 'naglfar',
#  190: 'nevermore',
#  191: 'old mans child',
#  192: 'shade empire',
#  193: 'system of a down',
#  194: 'tristania',
#  195: 'devendra banhart',
#  196: 'boards of canada',
#  197: 'cocorosie',
#  198: 'aphex twin',
#  199: 'atmosphere',
#  200: 'joanna newsom',
#  201: 'air',
#  202: 'portishead',
#  203: 'massive attack',
#  204: 'plaid',
#  205: 'fog',
#  206: 'prefuse 73',
#  207: 'm83',
#  208: 'the flashbulb',
#  209: 'pavement',
#  210: 'amon tobin',
#  211: 'sage francis',
#  212: 'four tet',
#  213: 'brother ali',
#  214: 'max richter',
#  215: 'why?',
#  216: 'autechre',
#  217: 'radiohead',
#  218: 'susumu yokota',
#  219: 'electrelane',
#  220: 'neutral milk hotel',
#  221: 'bent',
#  222: 'vetiver',
#  223: 'k-the-i???',
#  224: 'illogic',
#  225: 'annie',
#  226: 'broadcast',
#  227: 'beastie boys',
#  228: 'aesop rock',
#  229: 'mf doom',
#  230: 'the books',
#  231: 'bibio',
#  232: "rachel's",
#  233: 'architecture in helsinki',
#  234: 'bola',
#  235: 'isan',
#  236: 'apes & androids',
#  237: 'múm',
#  238: 'elliott smith',
#  239: 'caribou',
#  240: 'the hold steady',
#  241: 'mogwai',
#  242: 'justice',
#  243: 'sigur rós',
#  244: 'clutch',
#  245: 'white denim',
#  246: 'the go! team',
#  247: 'the beatles',
#  248: "2 many dj's",
#  249: 'tv on the radio',
#  250: 'kyuss',
#  251: 'dj shadow',
#  252: 'a tribe called quest',
#  253: 'the cinematic orchestra',
#  254: 'beck',
#  255: 'bon iver',
#  256: 'röyksopp',
#  257: 'rex the dog',
#  258: 'bonobo',
#  259: 'deadmau5',
#  260: 'the decemberists',
#  261: 'earth',
#  262: 'snow patrol',
#  263: 'battles',
#  264: 'metronomy',
#  265: 'dj format',
#  266: 'the prodigy',
#  267: 'lemon jelly',
#  268: 'pink floyd',
#  269: 'rjd2',
#  270: 'the flaming lips',
#  271: 'alasdair fraser & paul machlis',
#  272: 'passion pit',
#  273: 'holy fuck',
#  274: 'michael jackson',
#  275: 'late of the pier',
#  276: 'flight of the conchords',
#  277: 'muse',
#  278: 'fleetwood mac',
#  279: 'led zeppelin',
#  280: 'stam1na',
#  281: 'dream theater',
#  282: 'ac/dc',
#  283: 'metallica',
#  284: 'iron maiden',
#  285: 'bob marley & the wailers',
#  286: 'megadeth',
#  287: 'trivium',
#  288: 'raappana',
#  289: 'nightwish',
#  290: 'kotiteollisuus',
#  291: 'sublime',
#  292: 'viikate',
#  293: 'volbeat',
#  294: "guns n' roses",
#  295: 'bon jovi',
#  296: 'dio',
#  297: 'soldiers of jah army',
#  298: 'scorpions',
#  299: 'teräsbetoni',
#  300: 'nopsajalka',
#  301: 'paramore',
#  302: 'the darkness',
#  303: 'soul captain band',
#  304: 'asa',
#  305: 'tarot',
#  306: 'klamydia',
#  307: 'gentleman',
#  308: 'mötley crüe',
#  309: 'manowar',
#  310: 'killswitch engage',
#  311: 'slayer',
#  312: 'in flames',
#  313: 'skid row',
#  314: 'stone',
#  315: 'bullet for my valentine',
#  316: 'mokoma',
#  317: 'pantera',
#  318: 'brother firetribe',
#  319: 'hurriganes',
#  320: 'norther',
#  321: 'stratovarius',
#  322: 'kiuas',
#  323: 'ozzy osbourne',
#  324: 'pin',
#  325: 'feel',
#  326: 'elton john',
#  327: 'orgy',
#  328: 'brandy',
#  329: 'pet shop boys',
#  330: 'sade',
#  331: 'belinda carlisle',
#  332: 'eurythmics',
#  333: 'mike oldfield',
#  334: 'hall & oates',
#  335: 'chris rea',
#  336: 'laura branigan',
#  337: 'the waterboys',
#  338: 'maciej silski',
#  339: 'leona lewis',
#  340: 'george michael',
#  341: 'black',
#  342: 'frozen silence',
#  343: 'sweet coffee',
#  344: 'blackfield',
#  345: 'cyndi lauper',
#  346: 'pseudo echo',
#  347: 'desireless',
#  348: 'limp bizkit',
#  349: 'modern talking',
#  350: 'rihanna',
#  351: 'a-ha',
#  352: 'linkin park',
#  353: 'hans zimmer',
#  354: 'nelly furtado',
#  355: 'madonna',
#  356: 'blink-182',
#  357: 'dave gahan',
#  358: 'kelly clarkson',
#  359: 'lucie silvas',
#  360: 'natalie imbruglia',
#  361: 'michelle branch',
#  362: 'delta goodrem',
#  363: 'new order',
#  364: 'seal',
#  365: 'atomic kitten',
#  366: 'backstreet boys',
#  367: 'mary j. blige',
#  368: 'negative',
#  369: 'justin timberlake',
#  370: 'savage garden',
#  371: 'nerina pallot',
#  372: 'erasure',
#  373: 'culture club',
#  374: 'mr. oizo',
#  375: 'robbie williams',
#  376: 'black eyed peas',
#  377: 'antonio orozco',
#  378: 'decai',
#  379: 'kiko & shara',
#  380: 'marc anthony',
#  381: 'manuel carrasco',
#  382: 'mika',
#  383: 'juanes',
#  384: 'la oreja de van gogh',
#  385: 'melendi',
#  386: 'amaral',
#  387: 'andy & lucas',
#  388: 'chambao',
#  389: 'chayanne',
#  390: 'christian castro',
#  391: 'christina aguilera',
#  392: 'craig david',
#  393: 'luis fonsi',
#  394: 'sergio contreras',
#  395: 'ana torroja',
#  396: 'beyoncé',
#  397: 'bustamante',
#  398: 'camila',
#  399: 'colbie caillat',
#  400: 'coti',
#  401: 'david bisbal',
#  402: 'edurne',
#  403: 'fito & fitipaldis',
#  404: 'hanna',
#  405: 'malu',
#  406: 'paulina rubio',
#  407: 'rosana',
#  408: 't.a.t.u.',
#  409: 'amy winehouse',
#  410: 'efecto mariposa',
#  411: 'el arrebato',
#  412: 'enrique iglesias',
#  413: 'fondo flamenco',
#  414: 'jennifer lopez',
#  415: 'mecano',
#  416: 'phil collins',
#  417: 'sean kingston',
#  418: 'u2',
#  419: 'dub fx',
#  420: 'box car racer',
#  421: 'zebrahead',
#  422: 'paul oakenfold',
#  423: 'pendulum',
#  424: 'ronald jenkees',
#  425: 'sum 41',
#  426: 'angels & airwaves',
#  427: 'haggard',
#  428: 'alien ant farm',
#  429: 'the offspring',
#  430: 'океан ельзи',
#  431: 'ronan hardiman',
#  432: 'the crystal method',
#  433: '川田まみ',
#  434: 'eminem',
#  435: 'the qemists',
#  436: 'silverstein',
#  437: 'rise against',
#  438: 'бумбокс',
#  439: 'scum of the earth',
#  440: 'blu mar ten',
#  441: 'bomfunk mcs',
#  442: 'vanessa-mae',
#  443: 'тартак',
#  444: 'drop dead, gorgeous',
#  445: 'flying steps',
#  446: 'drumattic twins',
#  447: 'andrew w.k.',
#  448: 'hoobastank',
#  449: 'dover',
#  450: 'bodyjar',
#  451: 'southside rockers',
#  452: 'prodigy',
#  453: 'future prophecies',
#  454: 'jonathan coulton',
#  455: 'blessthefall',
#  456: 'nubreed & luke chable',
#  457: 'franz ferdinand',
#  458: 'johannes linstead',
#  459: 'infected mushroom',
#  460: 'darude',
#  461: 'akira yamaoka',
#  462: 'aqua',
#  463: 'clawfinger',
#  464: 'dusty kid',
#  465: 'senses fail',
#  466: 'commix',
#  467: 'id software',
#  468: 'panic at the disco',
#  469: 'enigma',
#  470: 'fatboy slim',
#  471: 'krs-one',
#  472: 'drowning pool',
#  473: 'placebo',
#  474: 'david & the citizens',
#  475: 'kent',
#  476: 'säkert!',
#  477: 'detektivbyrån',
#  478: 'lars winnerbäck',
#  479: 'raymond & maria',
#  480: 'tegan and sara',
#  481: 'the knife',
#  482: 'tiger lou',
#  483: 'håkan hellström',
#  484: 'david fridlund',
#  485: 'the ark',
#  486: 'alice in videoland',
#  487: 'timo räisänen',
#  488: 'the cardigans',
#  489: 'bloc party',
#  490: 'oasis',
#  491: 'sahara hotnights',
#  492: 'vapnet',
#  493: 'laleh',
#  494: 'markus krunegård',
#  495: 'the kooks',
#  496: 'deportees',
#  497: 'r.e.m.',
#  498: 'slagsmålsklubben',
#  499: 'hot chip',
#  500: 'millencolin',
#  501: 'the sounds',
#  502: 'mew',
#  503: 'green day',
#  504: 'kings of convenience',
#  505: 'firefox ak',
#  506: 'mando diao',
#  507: 'the tough alliance',
#  508: 'shout out louds',
#  509: 'keane',
#  510: 'wir sind helden',
#  511: 'thompson twins',
#  512: 'hanson',
#  513: 'no doubt',
#  514: 'orchestral manoeuvres in the dark',
#  515: 'the human league',
#  516: 'altered images',
#  517: 'martina mcbride',
#  518: 'yazoo',
#  519: 'regina spektor',
#  520: 'the format',
#  521: 'carolyn dawn johnson',
#  522: 'mazzy star',
#  523: 'dashboard confessional',
#  524: 'jonathan larson',
#  525: 'wicked',
#  526: 'the verve pipe',
#  527: 'missing persons',
#  528: 'the passions',
#  529: 'ima robot',
#  530: 'judith holofernes',
#  531: 'depeche mode',
#  532: 'fake',
#  533: 'der plan',
#  534: 'gwen stefani',
#  535: 'dierks bentley',
#  536: 'heaven 17',
#  537: 'the sundays',
#  538: 'dixie chicks',
#  539: 'shania twain',
#  540: 'stacey q',
#  541: 'camera obscura',
#  542: 'deana carter',
#  543: 'matt & kim',
#  544: 'steel train',
#  545: 'dan fogelberg',
#  546: 'taking back sunday',
#  547: 'andrew bird',
#  548: 'jewel',
#  549: 'haircut 100',
#  550: 'britney spears',
#  551: 'kristy lee',
#  552: 'the police',
#  553: 'the postal service',
#  554: 'fefe dobson',
#  555: 'julie roberts',
#  556: 'j dilla',
#  557: 'nas',
#  558: 'common',
#  559: 'black milk',
#  560: 'pete rock',
#  561: 'jay-z',
#  562: 'dr. dre',
#  563: 'evidence',
#  564: 'kanye west',
#  565: 'dead prez',
#  566: 'percee p',
#  567: 'jeff mills',
#  568: 'method man',
#  569: 'panacea',
#  570: '2pac',
#  571: 'fort minor',
#  572: 'madvillain',
#  573: 'ratatat',
#  574: 'talib kweli',
#  575: 'do or die',
#  576: 'madlib',
#  577: '50 cent',
#  578: 'abstract rude & tribe unique',
#  579: 'the alchemist',
#  580: 'bill evans',
#  581: 'gza/genius',
#  582: 'lil wayne',
#  583: 'styles p',
#  584: 'emc',
#  585: 'ghostface',
#  586: 'k-os',
#  587: 'burial',
#  588: 'dj vadim',
#  589: 'el-p',
#  590: 'big shug',
#  591: 'black spade',
#  592: 'john coltrane',
#  593: 'the residents',
#  594: 'roni size & reprazent',
#  595: 'flying lotus - (www.influencias-urbanas.blogspot.com)',
#  596: 'the cool kids',
#  597: 'the game',
#  598: 'redman',
#  599: 'rza',
#  600: 'joan baez',
#  601: 'e-rotic',
#  602: 'goo goo dolls',
#  603: 'apulanta',
#  604: 'chorale',
#  605: 'bryan adams',
#  606: 'gnarls barkley',
#  607: 'groove coverage',
#  608: 'september',
#  609: '3 doors down',
#  610: 'basic element',
#  611: 'chris brown',
#  612: 'eels',
#  613: 'solid base',
#  614: 'irwin goodman',
#  615: 'moby',
#  616: 'don huonot',
#  617: 'stella',
#  618: 'the pussycat dolls',
#  619: 'cascada',
#  620: 'john legend',
#  621: 'alicia keys',
#  622: 'kapasiteettiyksikkö',
#  623: 'sonata arctica',
#  624: 'frank sinatra',
#  625: 'jonas brothers',
#  626: 'deep insight',
#  627: 'maroon 5',
#  628: 'the calling',
#  629: 'ambassadöör',
#  630: 'cheek',
#  631: 'darin',
#  632: 'antti tuisku',
#  633: 'usher',
#  634: 'finlanders',
#  635: 'sadetanssi',
#  636: 'snoop dogg',
#  637: 'akon',
#  638: 'mamba',
#  639: 'da buzz',
#  640: 'jessy',
#  641: 'syd barrett',
#  642: 'spiritualized',
#  643: 'the boo radleys',
#  644: 'the brian jonestown massacre',
#  645: 'black rebel motorcycle club',
#  646: 'the duke spirit',
#  647: 'the stone roses',
#  648: 'jefferson airplane',
#  649: 'the black angels',
#  650: 'graham bond organisation',
#  651: 'love',
#  652: 'the warlocks',
#  653: 'a place to bury strangers',
#  654: 'not from there',
#  655: 'richard in your mind',
#  656: 'king khan & the shrines',
#  657: 'the stairs',
#  658: 'the vera violets',
#  659: "edgar 'jones' jones",
#  660: 'film school',
#  661: 'captain beefheart & his magic band',
#  662: 'the charlatans',
#  663: 'kaleidoscope',
#  664: 'the raconteurs',
#  665: 'dungen',
#  666: 'the velvet underground',
#  667: 'spindrift',
#  668: 'the incredible string band',
#  669: 'flavor crystals',
#  670: 'nico',
#  671: 'the dandy warhols',
#  672: 'asobi seksu',
#  673: 'stereolab',
#  674: 'fairport convention',
#  675: 'nick drake',
#  676: 'soft machine',
#  677: 'the greenhornes',
#  678: 'the national',
#  679: 'black mountain',
#  680: 'television',
#  681: 'the telescopes',
#  682: 'lostprophets',
#  683: 'all time low',
#  684: 'lucky boys confusion',
#  685: 'amber pacific',
#  686: 'four year strong',
#  687: 'fall out boy',
#  688: 'the weakerthans',
#  689: 'showoff',
#  690: '+44',
#  691: 'damien rice',
#  692: 'my chemical romance',
#  693: 'ben kweller',
#  694: 'foo fighters',
#  695: 'anberlin',
#  696: 'moving mountains',
#  697: 'the wedding',
#  698: 'frightened rabbit',
#  699: 'cartel',
#  700: 'saosin',
#  701: 'set your goals',
#  702: 'holiday parade',
#  703: 'cauterize',
#  704: 'nizlopi',
#  705: 'hit the lights',
#  706: 'get cape. wear cape. fly',
#  707: 'better luck next time',
#  708: 'girl talk',
#  709: 'story of the year',
#  710: 'joshua radin',
#  711: 'the frantic',
#  712: 'the ataris',
#  713: 'sufjan stevens',
#  714: 'sherwood',
#  715: 'norah jones',
#  716: 'madredeus',
#  717: 'așa',
#  718: 'carla bruni',
#  719: 'penguin cafe orchestra',
#  720: 'ravid goldschmidt',
#  721: 'humanos',
#  722: 'xutos & pontapés',
#  723: 'paul simon',
#  724: 'lily allen',
#  725: 'kid loco',
#  726: 'pedro abrunhosa',
#  727: 'stevie wonder',
#  728: 'thievery corporation',
#  729: 'the streets',
#  730: 'ratos de porão',
#  731: 'lady sovereign',
#  732: 'faith no more',
#  733: 'manu chao',
#  734: 'tenacious d',
#  735: 'fantômas',
#  736: 'type o negative',
#  737: 'pearl jam',
#  738: 'cali lewis',
#  739: 'the commitments',
#  740: 'soundgarden',
#  741: 'buckethead',
#  742: 'the cult',
#  743: 'rush',
#  744: 'king crimson',
#  745: 'camel',
#  746: 'amplifier',
#  747: 'uriah heep',
#  748: 'the answer',
#  749: 'yes',
#  750: 'disturbed',
#  751: 'jethro tull',
#  752: 'porcupine tree',
#  753: 'liquid tension experiment',
#  754: 'ted nugent',
#  755: 'wolfmother',
#  756: 'emerson, lake & palmer',
#  757: 'aerosmith',
#  758: 'iommi',
#  759: 'frankie goes to hollywood',
#  760: 'ufo',
#  761: 'days of the new',
#  762: 'caravan',
#  763: 'the verve',
#  764: 'rammstein',
#  765: 'wishbone ash',
#  766: 'the moody blues',
#  767: 'jordan rudess',
#  768: 'chevelle',
#  769: 'cream',
#  770: 'patti smith',
#  771: 'nickelback',
#  772: 'zz top',
#  773: 'nine inch nails',
#  774: 'my bloody valentine',
#  775: 'pj harvey',
#  776: 'the cure',
#  777: 'nick cave and the bad seeds',
#  778: 'the jesus and mary chain',
#  779: 'the sisters of mercy',
#  780: 'david bowie',
#  781: 'a perfect circle',
#  782: 'the white stripes',
#  783: 'the dresden dolls',
#  784: 'nouvelle vague',
#  785: 'leonard cohen',
#  786: 'rowland s. howard',
#  787: 'creedence clearwater revival',
#  788: 'goon moon',
#  789: 'grinderman',
#  790: 'gary numan',
#  791: 'slowdive',
#  792: 'the boys next door',
#  793: 'beirut',
#  794: 'joy division',
#  795: 'clint mansell',
#  796: 'inkubus sukkubus',
#  797: 'the smiths',
#  798: 'cat power',
#  799: 'nick cave & warren ellis',
#  800: 'anita lane',
#  801: 'bauhaus',
#  802: 'amiina',
#  803: 'bajaga',
#  804: 'interpol',
#  805: 'the 69 eyes',
#  806: 'christian death',
#  807: 'the stooges',
#  808: 'iggy pop',
#  809: 'grave digger',
#  810: 'running wild',
#  811: 'primal fear',
#  812: 'paragon',
#  813: 'iced earth',
#  814: 'lamb of god',
#  815: 'u.d.o.',
#  816: 'annihilator',
#  817: 'exodus',
#  818: 'exciter',
#  819: 'strapping young lad',
#  820: 'kreator',
#  821: 'rebellion',
#  822: 'sabaton',
#  823: 'helloween',
#  824: 'iron savior',
#  825: 'accept',
#  826: '3 inches of blood',
#  827: 'jag panzer',
#  828: 'mastodon',
#  829: 'steel attack',
#  830: 'daath',
#  831: 'metal church',
#  832: 'gojira',
#  833: 'devildriver',
#  834: 'decapitated',
#  835: 'hammerfall',
#  836: 'the ocean',
#  837: 'hatebreed',
#  838: 'mortification',
#  839: 'halford',
#  840: 'meshuggah',
#  841: 'finntroll',
#  842: 'gamma ray',
#  843: 'stormwarrior',
#  844: 'fight',
#  845: 'vicious rumors',
#  846: 'dream evil',
#  847: 'necrophagist',
#  848: 'rage',
#  849: 'morgana lefay',
#  850: 'chiodos',
#  851: 'black tequila',
#  852: '30 seconds to mars',
#  853: 'as i lay dying',
#  854: 'a static lullaby',
#  855: 'billy talent',
#  856: 'bosse',
#  857: 'deus',
#  858: 'feeder',
#  859: 'funeral for a friend',
#  860: 'a day to remember',
#  861: 'beatsteaks',
#  862: 'coheed and cambria',
#  863: 'dúné',
#  864: 'enter shikari',
#  865: 'finch',
#  866: 'from first to last',
#  867: 'lostalone',
#  868: 'mindless self indulgence',
#  869: 'olli schulz & der hund marie',
#  870: 'slut',
#  871: 'the dreaming',
#  872: 'alesana',
#  873: 'ash',
#  874: 'brand new',
#  875: 'canoe',
#  876: 'kill hannah',
#  877: 'madsen',
#  878: 'maxïmo park',
#  879: 'neaera',
#  880: 'scary kids scaring kids',
#  881: 'secret and whisper',
#  882: 'the fall of troy',
#  883: 'the vines',
#  884: 'virginia jetzt!',
#  885: 'as we fight',
#  886: 'grammatics',
#  887: 'tele',
#  888: 'underoath',
#  889: 'parragon books',
#  890: 'michael armstrong',
#  891: 'alkaline trio',
#  892: 'afi',
#  893: 'tiger army',
#  894: 'elvis costello',
#  895: 'elvis presley',
#  896: 'the mighty mighty bosstones',
#  897: 'adema',
#  898: 'foghat',
#  899: 'kylie minogue',
#  900: 'foxboro hot tubs',
#  901: 'pink',
#  902: 'tim mcgraw',
#  903: 'dead to me',
#  904: 'mxpx',
#  905: 'bad religion',
#  906: 'jimmy eat world',
#  907: 'the gaslight anthem',
#  908: 'danny elfman',
#  909: 'dead kennedys',
#  910: 'nirvana',
#  911: 'the tantra monsters',
#  912: 'poison',
#  913: 'me first and the gimme gimmes',
#  914: 'mgm studio orchestra',
#  915: 'new found glory',
#  916: 'agnostic front',
#  917: 'all',
#  918: 'marilyn manson',
#  919: 'rancid',
#  920: 'less than jake',
#  921: 'my life with the thrill kill kult',
#  922: 'the aquabats',
#  923: 'the distillers',
#  924: 'skarface',
#  925: 'mad caddies',
#  926: 'nofx',
#  927: 'cypress hill',
#  928: 'koяn',
#  929: 'the planet smashers',
#  930: 'reel big fish',
#  931: 'ska-p',
#  932: 'moskovskaya',
#  933: 'onyx',
#  934: 'belvedere',
#  935: 'distemper',
#  936: 'aventura',
#  937: "5'nizza",
#  938: 'captain everything!',
#  939: 'bob marley',
#  940: 'slipknot',
#  941: 'alizée',
#  942: 'electrosoul system',
#  943: 'richard cheese',
#  944: 'avril lavigne',
#  945: 'otklonenie',
#  946: 'cidade negra',
#  947: 'talco',
#  948: 'f.p.g.',
#  949: 'the specials',
#  950: 'daddy yankee',
#  951: 'skaface',
#  952: 'tina charles',
#  953: 'yeah yeah yeahs',
#  954: 'the dead weather',
#  955: 'no age',
#  956: 'tiny masters of today',
#  957: 'japandroids',
#  958: 'the used',
#  959: 'veto',
#  960: 'friendly fires',
#  961: 'hateen',
#  962: 'onerepublic',
#  963: 'dead fish',
#  964: 'sixpence none the richer',
#  965: 'peter bjorn and john',
#  966: 'thursday',
#  967: 'weezer',
#  968: 'japanther',
#  969: 'kings of leon',
#  970: "rock'n'zombie",
#  971: 'feist',
#  972: 'klaxons',
#  973: 'cansei de ser sexy',
#  974: 'does it offend you, yeah?',
#  975: 'twilight',
#  976: 'grease',
#  977: 'kaiser chiefs',
#  978: 'pelle miljoona',
#  979: 'ripsipiirakka',
#  980: 'orson',
#  981: 'frankie valli',
#  982: 'motion city soundtrack',
#  983: 'kuningas pähkinä & setä tamu',
#  984: 'genesis',
#  985: 'jukka poika',
#  986: 'technotronic',
#  987: 'robert pattinson',
#  988: 'stig dogg',
#  989: 'aviation',
#  990: 'high school musical 2',
#  991: 'kapteeni ä-ni',
#  992: 'ramones',
#  993: 'fools garden',
#  994: 'bone thugs-n-harmony',
#  995: 'rufus wainwright',
#  996: 'iron & wine',
#  997: 'blue foundation',
#  998: 'lemon ice',
#  999: 'the black ghosts',
#  ...}

# %%
def get_similar_artist(artist_name: str):
    artist_id = artist_to_idx[artist_name]
    similar_artist = als_model.similar_items(artist_id)
    similar_artist = [idx_to_artist[i[0]] for i in similar_artist]
    return similar_artist

print("슝=3")
# Out:
# 슝=3

# %%
get_similar_artist('coldplay')
get_similar_artist('2pac')
#get_similar_artist('lady gaga')
# Out:
# ['2pac',
#  'the game',
#  'nas',
#  'jay-z',
#  'dr. dre',
#  'notorious b.i.g.',
#  'snoop dogg',
#  '50 cent',
#  't.i.',
#  'ice cube']

# %%
user = user_to_idx['zimin']
# recommend에서는 user*item CSR Matrix를 받습니다.
artist_recommended = als_model.recommend(user, csr_data, N=20, filter_already_liked_items=True)
artist_recommended
# Out:
# [(350, 0.4386909),
#  (627, 0.43033814),
#  (550, 0.42770928),
#  (369, 0.42756903),
#  (354, 0.4240628),
#  (1800, 0.4118456),
#  (355, 0.39928013),
#  (274, 0.39003205),
#  (391, 0.3876658),
#  (621, 0.38261226),
#  (2249, 0.37142202),
#  (564, 0.36780363),
#  (901, 0.3632867),
#  (5555, 0.35593942),
#  (944, 0.35241556),
#  (618, 0.35020515),
#  (7317, 0.3496516),
#  (24, 0.3467919),
#  (1777, 0.3453881),
#  (409, 0.3430565)]

# %%
[idx_to_artist[i[0]] for i in artist_recommended]
# Out:
# ['rihanna',
#  'maroon 5',
#  'britney spears',
#  'justin timberlake',
#  'nelly furtado',
#  'lady gaga',
#  'madonna',
#  'michael jackson',
#  'christina aguilera',
#  'alicia keys',
#  'katy perry',
#  'kanye west',
#  'pink',
#  'timbaland',
#  'avril lavigne',
#  'the pussycat dolls',
#  'fergie',
#  'jack johnson',
#  'mariah carey',
#  'amy winehouse']

# %%
rihanna = artist_to_idx['rihanna']
explain = als_model.explain(user, csr_data, itemid=rihanna)

# %%
[(idx_to_artist[i[0]], i[1]) for i in explain[1]]
# Out:
# [('beyoncé', 0.22607968377320475),
#  ('black eyed peas', 0.12319947839444169),
#  ('jason mraz', 0.056435922246165844),
#  ('coldplay', 0.03478911426967534),
#  ('maroon5', 0.00022470280368385953)]
