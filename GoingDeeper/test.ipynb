# %%
# !ls
# Out:
# aiffel

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
# Tensorflow가 활용할 GPU가 장착되어 있는지 확인해 봅니다.
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import urllib3
urllib3.disable_warnings()

#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.

(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)

# %%
print(ds_info.features)
# Out:
# FeaturesDict({
#     'id': Text(shape=(), dtype=tf.string),
#     'image': Image(shape=(32, 32, 3), dtype=tf.uint8),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
# })

# %%
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(50000, shape=(), dtype=int64)
# tf.Tensor(10000, shape=(), dtype=int64)

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    # image = tf.image.resize(image, [32, 32])
    return tf.cast(image, tf.float32) / 255., label

# %%
def apply_normalize_on_dataset(ds,is_test=False,batch_size=16):
    ds = ds.map(
        normalize_and_resize_img,
        num_parallel_calls=1
    )

    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
ds_info.features["label"].num_classes
# Out:
# 10

# %%
ds_info.features["label"].names
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
fig = tfds.show_examples(ds_train,ds_info)

# %%
fig = tfds.show_examples(ds_test,ds_info)

# %%
# function for building VGG Block

def build_vgg_block(input_layer,
                    num_cnn=3, 
                    channel=64,
                    block_num=1,
                   ):
    # 입력 레이어
    x = input_layer

    # CNN 레이어
    for cnn_num in range(num_cnn):
        x = keras.layers.Conv2D(
            filters=channel,
            kernel_size=(3,3),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_conv{cnn_num}'
        )(x)    

    # Max Pooling 레이어
    x = keras.layers.MaxPooling2D(
        pool_size=(2, 2),
        strides=2,
        name=f'block{ }_pooling'
    )(x)

    return x

# %%
vgg_input_layer = keras.layers.Input(shape=(32,32,3))   # 입력 레이어 생성
vgg_block_output = build_vgg_block(vgg_input_layer)    # VGG 블록 생성

# %%
# 블록 1개짜리 model 생성
model = keras.Model(inputs=vgg_input_layer, outputs=vgg_block_output)  

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 16, 16, 64)        0
# =================================================================
# Total params: 75,648
# Trainable params: 75,648
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VGG 모델 자체를 생성하는 함수입니다.
def build_vgg(input_shape=(32,32,3),
              num_cnn_list=[2,2,3,3,3],
              channel_list=[64,128,256,512,512],
              num_classes=10):
    
    assert len(num_cnn_list) == len(channel_list) #모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.
    
    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
    output = input_layer
    
    # config list들의 길이만큼 반복해서 블록을 생성합니다.
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        output = build_vgg_block(
            output,
            num_cnn=num_cnn,
            channel=channel,
            block_num=i
        )
        
    output = keras.layers.Flatten(name='flatten')(output)
    output = keras.layers.Dense(4096, activation='relu', name='fc1')(output)
    output = keras.layers.Dense(4096, activation='relu', name='fc2')(output)
    output = keras.layers.Dense(num_classes, activation='softmax', name='predictions')(output)
    
    model = keras.Model(
        inputs=input_layer, 
        outputs=output
    )
    return model

# %%
def resnet_50(input_shape = (32,32,3)):
    input_layer = keras.layers.Input(shape = input_shape)
    x = input_layer

    x = keras.layers.ZeroPadding2D((3,3))(x)
    x = keras.layers.Conv2D(64,(7,7),strides=(2,2),padding='valid')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation('relu')(x)

    

    model = keras.Model(inputs = input_layer, outputs = x)
    return model

# %%
# 기본값을 그대로 사용해서 VGG 모델을 만들면 VGG-16이 됩니다.
vgg_16 = build_vgg()

vgg_16.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block0_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block0_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block0_pooling (MaxPooling2D (None, 16, 16, 64)        0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 8, 8, 128)         0
# _________________________________________________________________
# block2_conv0 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_pooling (MaxPooling2D (None, 4, 4, 256)         0
# _________________________________________________________________
# block3_conv0 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_pooling (MaxPooling2D (None, 2, 2, 512)         0
# _________________________________________________________________
# block4_conv0 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_pooling (MaxPooling2D (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 10)                40970
# =================================================================
# Total params: 33,638,218
# Trainable params: 33,638,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 원하는 블록의 설계에 따라 매개변수로 리스트를 전달해 줍니다.
vgg_19 = build_vgg(
    num_cnn_list=[2,2,4,4,4],
    channel_list=[64,128,256,512,512]
)

vgg_19.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block0_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block0_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block0_pooling (MaxPooling2D (None, 16, 16, 64)        0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 8, 8, 128)         0
# _________________________________________________________________
# block2_conv0 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_pooling (MaxPooling2D (None, 4, 4, 256)         0
# _________________________________________________________________
# block3_conv0 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_pooling (MaxPooling2D (None, 2, 2, 512)         0
# _________________________________________________________________
# block4_conv0 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_pooling (MaxPooling2D (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 10)                40970
# =================================================================
# Total params: 38,947,914
# Trainable params: 38,947,914
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE = 256
EPOCH = 20

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
vgg_16.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_16 = vgg_16.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/20
# 195/195 [==============================] - 81s 374ms/step - loss: 2.2341 - accuracy: 0.1619 - val_loss: 2.0637 - val_accuracy: 0.2629
# Epoch 2/20
# 195/195 [==============================] - 58s 299ms/step - loss: 2.0315 - accuracy: 0.2661 - val_loss: 1.9684 - val_accuracy: 0.2931
# Epoch 3/20
# 195/195 [==============================] - 50s 258ms/step - loss: 1.8928 - accuracy: 0.3165 - val_loss: 1.8351 - val_accuracy: 0.3425
# Epoch 4/20
# 195/195 [==============================] - 50s 259ms/step - loss: 1.7681 - accuracy: 0.3604 - val_loss: 1.6938 - val_accuracy: 0.3948
# Epoch 5/20
# 195/195 [==============================] - 50s 259ms/step - loss: 1.6841 - accuracy: 0.3944 - val_loss: 1.6047 - val_accuracy: 0.4248
# Epoch 6/20
# 195/195 [==============================] - 50s 259ms/step - loss: 1.6202 - accuracy: 0.4177 - val_loss: 1.5843 - val_accuracy: 0.4338
# Epoch 7/20
# 195/195 [==============================] - 50s 259ms/step - loss: 1.5643 - accuracy: 0.4406 - val_loss: 1.5399 - val_accuracy: 0.4527
# Epoch 8/20
# 195/195 [==============================] - 50s 259ms/step - loss: 1.5178 - accuracy: 0.4565 - val_loss: 1.4555 - val_accuracy: 0.4752
# Epoch 9/20
# 195/195 [==============================] - 50s 259ms/step - loss: 1.4714 - accuracy: 0.4685 - val_loss: 1.4252 - val_accuracy: 0.4910
# Epoch 10/20
# 195/195 [==============================] - 51s 259ms/step - loss: 1.4337 - accuracy: 0.4821 - val_loss: 1.4128 - val_accuracy: 0.4930
# Epoch 11/20
# 195/195 [==============================] - 50s 258ms/step - loss: 1.3925 - accuracy: 0.5041 - val_loss: 1.3966 - val_accuracy: 0.4914
# Epoch 12/20
# 195/195 [==============================] - 51s 261ms/step - loss: 1.3497 - accuracy: 0.5214 - val_loss: 1.3928 - val_accuracy: 0.4934
# Epoch 13/20
# 195/195 [==============================] - 51s 260ms/step - loss: 1.3108 - accuracy: 0.5305 - val_loss: 1.2666 - val_accuracy: 0.5442
# Epoch 14/20
# 195/195 [==============================] - 50s 259ms/step - loss: 1.2772 - accuracy: 0.5448 - val_loss: 1.2888 - val_accuracy: 0.5377
# Epoch 15/20
# 195/195 [==============================] - 51s 259ms/step - loss: 1.2545 - accuracy: 0.5531 - val_loss: 1.2853 - val_accuracy: 0.5374
# Epoch 16/20
# 195/195 [==============================] - 50s 258ms/step - loss: 1.2128 - accuracy: 0.5665 - val_loss: 1.2426 - val_accuracy: 0.5623
# Epoch 17/20
# 195/195 [==============================] - 50s 259ms/step - loss: 1.1842 - accuracy: 0.5787 - val_loss: 1.2153 - val_accuracy: 0.5643
# Epoch 18/20
# 195/195 [==============================] - 50s 257ms/step - loss: 1.1641 - accuracy: 0.5871 - val_loss: 1.2243 - val_accuracy: 0.5694
# Epoch 19/20
# 195/195 [==============================] - 50s 258ms/step - loss: 1.1291 - accuracy: 0.5989 - val_loss: 1.1888 - val_accuracy: 0.5740
# Epoch 20/20
# 195/195 [==============================] - 51s 261ms/step - loss: 1.1084 - accuracy: 0.6055 - val_loss: 1.2058 - val_accuracy: 0.5754

# %%
vgg_19.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_19 = vgg_19.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/20
# 195/195 [==============================] - 68s 304ms/step - loss: 2.2740 - accuracy: 0.1400 - val_loss: 2.1093 - val_accuracy: 0.2184
# Epoch 2/20
# 195/195 [==============================] - 59s 303ms/step - loss: 2.0824 - accuracy: 0.2340 - val_loss: 1.9535 - val_accuracy: 0.2834
# Epoch 3/20
# 195/195 [==============================] - 59s 304ms/step - loss: 1.9367 - accuracy: 0.2931 - val_loss: 1.7903 - val_accuracy: 0.3469
# Epoch 4/20
# 195/195 [==============================] - 59s 304ms/step - loss: 1.8074 - accuracy: 0.3424 - val_loss: 1.7135 - val_accuracy: 0.3743
# Epoch 5/20
# 195/195 [==============================] - 60s 306ms/step - loss: 1.6987 - accuracy: 0.3835 - val_loss: 1.6545 - val_accuracy: 0.4181
# Epoch 6/20
# 195/195 [==============================] - 60s 306ms/step - loss: 1.6335 - accuracy: 0.4097 - val_loss: 1.5994 - val_accuracy: 0.4165
# Epoch 7/20
# 195/195 [==============================] - 59s 305ms/step - loss: 1.5760 - accuracy: 0.4324 - val_loss: 1.5211 - val_accuracy: 0.4594
# Epoch 8/20
# 195/195 [==============================] - 59s 305ms/step - loss: 1.5217 - accuracy: 0.4489 - val_loss: 1.4591 - val_accuracy: 0.4703
# Epoch 9/20
# 195/195 [==============================] - 59s 305ms/step - loss: 1.4818 - accuracy: 0.4655 - val_loss: 1.4595 - val_accuracy: 0.4811
# Epoch 10/20
# 195/195 [==============================] - 60s 306ms/step - loss: 1.4281 - accuracy: 0.4840 - val_loss: 1.4634 - val_accuracy: 0.4845
# Epoch 11/20
# 195/195 [==============================] - 59s 305ms/step - loss: 1.3877 - accuracy: 0.4971 - val_loss: 1.3721 - val_accuracy: 0.5058
# Epoch 12/20
# 195/195 [==============================] - 59s 305ms/step - loss: 1.3521 - accuracy: 0.5183 - val_loss: 1.3422 - val_accuracy: 0.5237
# Epoch 13/20
# 195/195 [==============================] - 59s 305ms/step - loss: 1.3083 - accuracy: 0.5301 - val_loss: 1.2776 - val_accuracy: 0.5412
# Epoch 14/20
# 195/195 [==============================] - 60s 306ms/step - loss: 1.2696 - accuracy: 0.5423 - val_loss: 1.2686 - val_accuracy: 0.5515
# Epoch 15/20
# 195/195 [==============================] - 60s 305ms/step - loss: 1.2343 - accuracy: 0.5609 - val_loss: 1.2376 - val_accuracy: 0.5563
# Epoch 16/20
# 195/195 [==============================] - 59s 305ms/step - loss: 1.1904 - accuracy: 0.5753 - val_loss: 1.2470 - val_accuracy: 0.5553
# Epoch 17/20
# 195/195 [==============================] - 60s 306ms/step - loss: 1.1728 - accuracy: 0.5839 - val_loss: 1.2266 - val_accuracy: 0.5638
# Epoch 18/20
# 195/195 [==============================] - 59s 304ms/step - loss: 1.1324 - accuracy: 0.5929 - val_loss: 1.2056 - val_accuracy: 0.5733
# Epoch 19/20
# 195/195 [==============================] - 59s 305ms/step - loss: 1.1089 - accuracy: 0.6046 - val_loss: 1.1906 - val_accuracy: 0.5917
# Epoch 20/20
# 195/195 [==============================] - 59s 305ms/step - loss: 1.0781 - accuracy: 0.6144 - val_loss: 1.1494 - val_accuracy: 0.5962

# %%
import matplotlib.pyplot as plt

plt.plot(history_16.history['loss'], 'r')
plt.plot(history_19.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['vgg_16', 'vgg_19'], loc='upper left')
plt.show()

# %%
plt.plot(history_16.history['val_accuracy'], 'r')
plt.plot(history_19.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['vgg_16', 'vgg_19'], loc='upper left')
plt.show()
